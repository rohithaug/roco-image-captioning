# %%
# params
test_valid_percentage = 30 # (test - 15, valid - 15)

train_data_percentage = 60
valid_data_percentage = 60
test_data_percentage = 60

max_target_length = 256

# %%
import os
import re
import json
import torch
import numpy as np
import pandas as pd
from PIL import Image

# %%
from transformers import VisionEncoderDecoderModel, AutoFeatureExtractor,AutoTokenizer
os.environ["WANDB_DISABLED"] = "true"

# %%
import nltk
try:
    nltk.data.find("tokenizers/punkt")
except (LookupError, OSError):
    nltk.download("punkt", quiet=True)

# %% [markdown]
# ## Initialize VisionEncoderDecoderModelPermalink

# %%
from transformers import VisionEncoderDecoderModel, AutoTokenizer, AutoFeatureExtractor

image_encoder_model = "google/vit-base-patch16-224-in21k"
text_decode_model = "gpt2"

model = VisionEncoderDecoderModel.from_encoder_decoder_pretrained(image_encoder_model, text_decode_model)
# Out:
# Some weights of GPT2LMHeadModel were not initialized from the model checkpoint at gpt2 and are newly initialized: ['h.8.crossattention.bias', 'h.6.crossattention.q_attn.weight', 'h.2.crossattention.masked_bias', 'h.5.crossattention.c_proj.bias', 'h.10.crossattention.c_attn.weight', 'h.5.crossattention.c_proj.weight', 'h.4.crossattention.masked_bias', 'h.5.crossattention.bias', 'h.11.crossattention.masked_bias', 'h.5.ln_cross_attn.weight', 'h.8.crossattention.c_proj.weight', 'h.9.crossattention.c_attn.weight', 'h.9.crossattention.c_proj.weight', 'h.0.ln_cross_attn.weight', 'h.4.crossattention.c_attn.weight', 'h.1.crossattention.c_proj.weight', 'h.4.ln_cross_attn.weight', 'h.7.crossattention.c_proj.weight', 'h.1.crossattention.q_attn.weight', 'h.7.crossattention.q_attn.weight', 'h.2.crossattention.bias', 'h.3.ln_cross_attn.weight', 'h.7.ln_cross_attn.weight', 'h.6.crossattention.c_attn.weight', 'h.1.ln_cross_attn.weight', 'h.11.crossattention.c_proj.bias', 'h.10.crossattention.c_proj.bias', 'h.0.crossattention.bias', 'h.0.crossattention.c_attn.weight', 'h.7.crossattention.c_proj.bias', 'h.7.crossattention.bias', 'h.10.ln_cross_attn.weight', 'h.5.crossattention.c_attn.weight', 'h.0.crossattention.c_proj.bias', 'h.11.crossattention.c_proj.weight', 'h.6.crossattention.bias', 'h.1.crossattention.c_attn.weight', 'h.2.crossattention.c_proj.bias', 'h.7.crossattention.masked_bias', 'h.9.ln_cross_attn.weight', 'h.0.crossattention.q_attn.weight', 'h.9.crossattention.c_proj.bias', 'h.10.crossattention.masked_bias', 'h.9.crossattention.bias', 'h.0.crossattention.masked_bias', 'h.4.crossattention.c_proj.bias', 'h.5.crossattention.masked_bias', 'h.3.crossattention.bias', 'h.2.ln_cross_attn.weight', 'h.1.crossattention.c_proj.bias', 'h.7.crossattention.c_attn.weight', 'h.4.crossattention.bias', 'h.4.crossattention.q_attn.weight', 'h.8.crossattention.q_attn.weight', 'h.3.crossattention.q_attn.weight', 'h.2.crossattention.c_proj.weight', 'h.6.crossattention.c_proj.bias', 'h.1.crossattention.masked_bias', 'h.3.crossattention.masked_bias', 'h.8.crossattention.c_attn.weight', 'h.8.crossattention.c_proj.bias', 'h.11.crossattention.c_attn.weight', 'h.2.crossattention.c_attn.weight', 'h.10.crossattention.c_proj.weight', 'h.10.crossattention.q_attn.weight', 'h.6.crossattention.masked_bias', 'h.9.crossattention.q_attn.weight', 'h.6.ln_cross_attn.weight', 'h.9.crossattention.masked_bias', 'h.0.crossattention.c_proj.weight', 'h.3.crossattention.c_attn.weight', 'h.8.ln_cross_attn.weight', 'h.3.crossattention.c_proj.weight', 'h.5.crossattention.q_attn.weight', 'h.1.crossattention.bias', 'h.2.crossattention.q_attn.weight', 'h.11.crossattention.q_attn.weight', 'h.11.ln_cross_attn.weight', 'h.10.crossattention.bias', 'h.4.crossattention.c_proj.weight', 'h.6.crossattention.c_proj.weight', 'h.8.crossattention.masked_bias', 'h.11.crossattention.bias', 'h.3.crossattention.c_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# image feature extractor
feature_extractor = AutoFeatureExtractor.from_pretrained(image_encoder_model)
# text tokenizer
tokenizer = AutoTokenizer.from_pretrained(text_decode_model)

# %%
# GPT2 only has bos/eos tokens but not decoder_start/pad tokens
tokenizer.pad_token = tokenizer.eos_token

# update the model config
model.config.eos_token_id = tokenizer.eos_token_id
model.config.decoder_start_token_id = tokenizer.bos_token_id
model.config.pad_token_id = tokenizer.pad_token_id

# %%
output_dir = "vit-gpt-model"
model.save_pretrained(output_dir)
feature_extractor.save_pretrained(output_dir)
tokenizer.save_pretrained(output_dir)
# Out:
# ('vit-gpt-model\\tokenizer_config.json',
#  'vit-gpt-model\\special_tokens_map.json',
#  'vit-gpt-model\\vocab.json',
#  'vit-gpt-model\\merges.txt',
#  'vit-gpt-model\\added_tokens.json',
#  'vit-gpt-model\\tokenizer.json')

# %% [markdown]
# ## Data Loading and Preparation

# %%
# file paths data
image_dir = './all_data/train/radiology/images/'
data_file = './all_data/train/radiology/traindata.csv'

# %%
data = pd.read_csv(data_file)
data
# Out:
#                id                                           name  \
# 0      ROCO_00002                 PMC4083729_AMHSR-4-14-g002.jpg
# 1      ROCO_00003              PMC2837471_IJD2009-150251.001.jpg
# 2      ROCO_00004         PMC2505281_11999_2007_30_Fig6_HTML.jpg
# 3      ROCO_00005              PMC3745845_IJD2013-683423.005.jpg
# 4      ROCO_00007          PMC4917066_amjcaserep-17-301-g001.jpg
# ...           ...                                            ...
# 65445  ROCO_81819  PMC3517833_CRIM.HEMATOLOGY2012-490438.001.jpg
# 65446  ROCO_81820               PMC5487234_rb-50-03-0190-g13.jpg
# 65447  ROCO_81821                 PMC2974222_kjr-11-612-g001.jpg
# 65448  ROCO_81822                 PMC3532764_AJNS-7-151-g002.jpg
# 65449  ROCO_81823               PMC3509000_pone.0050319.g002.jpg
#
#                                                  caption
# 0       Computed tomography scan in axial view showin...
# 1       Bacterial contamination occurred after comple...
# 2       The patient had residual paralysis of the han...
# 3        Panoramic radiograph after immediate loading.\n
# 4       Plain abdomen x-ray: Multiple air levels at t...
# ...                                                  ...
# 65445   Initial CT abdomen with contrast showing a di...
# 65446   44-year-old male patient after surgical amput...
# 65447   Primary pulmonary tuberculosis in 18-year-old...
# 65448   MRI brain with gadolinium, coronal view, show...
# 65449   Contrast-enhanced 3D MRL image of the lower e...
#
# [65450 rows x 3 columns]

# %%
# Replace column name 'name' with 'image_path'
data['image_path'] = data.pop('name')

# Prepend 'image_dir' to all entries in 'image_path' column
data['image_path'] = image_dir + data['image_path']

data
# Out:
#                id                                            caption  \
# 0      ROCO_00002   Computed tomography scan in axial view showin...
# 1      ROCO_00003   Bacterial contamination occurred after comple...
# 2      ROCO_00004   The patient had residual paralysis of the han...
# 3      ROCO_00005    Panoramic radiograph after immediate loading.\n
# 4      ROCO_00007   Plain abdomen x-ray: Multiple air levels at t...
# ...           ...                                                ...
# 65445  ROCO_81819   Initial CT abdomen with contrast showing a di...
# 65446  ROCO_81820   44-year-old male patient after surgical amput...
# 65447  ROCO_81821   Primary pulmonary tuberculosis in 18-year-old...
# 65448  ROCO_81822   MRI brain with gadolinium, coronal view, show...
# 65449  ROCO_81823   Contrast-enhanced 3D MRL image of the lower e...
#
#                                               image_path
# 0      ./all_data/train/radiology/images/PMC4083729_A...
# 1      ./all_data/train/radiology/images/PMC2837471_I...
# 2      ./all_data/train/radiology/images/PMC2505281_1...
# 3      ./all_data/train/radiology/images/PMC3745845_I...
# 4      ./all_data/train/radiology/images/PMC4917066_a...
# ...                                                  ...
# 65445  ./all_data/train/radiology/images/PMC3517833_C...
# 65446  ./all_data/train/radiology/images/PMC5487234_r...
# 65447  ./all_data/train/radiology/images/PMC2974222_k...
# 65448  ./all_data/train/radiology/images/PMC3532764_A...
# 65449  ./all_data/train/radiology/images/PMC3509000_p...
#
# [65450 rows x 3 columns]

# %%
for index, row in data.iterrows():
    image_path = row['image_path']
    if not os.path.exists(image_path):
        data.drop(index, inplace=True)
    else:
        try:
            image = Image.open(image_path)
        except Exception:
            data.drop(index, inplace=True)
        
# Reset the index after dropping rows
data.reset_index(drop=True, inplace=True)

data
# Out:
#                id                                            caption  \
# 0      ROCO_00002   Computed tomography scan in axial view showin...
# 1      ROCO_00003   Bacterial contamination occurred after comple...
# 2      ROCO_00004   The patient had residual paralysis of the han...
# 3      ROCO_00005    Panoramic radiograph after immediate loading.\n
# 4      ROCO_00007   Plain abdomen x-ray: Multiple air levels at t...
# ...           ...                                                ...
# 65414  ROCO_81819   Initial CT abdomen with contrast showing a di...
# 65415  ROCO_81820   44-year-old male patient after surgical amput...
# 65416  ROCO_81821   Primary pulmonary tuberculosis in 18-year-old...
# 65417  ROCO_81822   MRI brain with gadolinium, coronal view, show...
# 65418  ROCO_81823   Contrast-enhanced 3D MRL image of the lower e...
#
#                                               image_path
# 0      ./all_data/train/radiology/images/PMC4083729_A...
# 1      ./all_data/train/radiology/images/PMC2837471_I...
# 2      ./all_data/train/radiology/images/PMC2505281_1...
# 3      ./all_data/train/radiology/images/PMC3745845_I...
# 4      ./all_data/train/radiology/images/PMC4917066_a...
# ...                                                  ...
# 65414  ./all_data/train/radiology/images/PMC3517833_C...
# 65415  ./all_data/train/radiology/images/PMC5487234_r...
# 65416  ./all_data/train/radiology/images/PMC2974222_k...
# 65417  ./all_data/train/radiology/images/PMC3532764_A...
# 65418  ./all_data/train/radiology/images/PMC3509000_p...
#
# [65419 rows x 3 columns]

# %%
# # LLM output
# f = open('./all_data/llm_result.txt', "r")
# contents = f.read()
# contents = contents.replace("\n", "")
# json_data = json.loads(contents)

# llm_df = pd.DataFrame(json_data)

# llm_df = llm_df.drop('index', axis=1)

# llm_df = llm_df[llm_df['relationship'].apply(lambda x: re.search(r'\w', str(x)) is not None)]
# llm_df = llm_df.reset_index(drop=True)

# llm_df

# %%
# # Filter ones that have been training by the LLM
# data = data.merge(llm_df, on='id')
# data

# %%
from sklearn.model_selection import train_test_split

# Split data into train, test, and valid datasets
train_data, valid_test_data = train_test_split(data, test_size=test_valid_percentage/100, random_state=42)
valid_data, test_data = train_test_split(valid_test_data, test_size=0.5, random_state=42)

# Reset index
train_data = train_data.reset_index(drop=True)
valid_data = valid_data.reset_index(drop=True)
test_data = test_data.reset_index(drop=True)

# %%
print("Train data shape: ", train_data.shape)
print("Valid data shape: ", valid_data.shape)
print("Test data shape: ", test_data.shape)
# Out:
# Train data shape:  (45793, 3)
# Valid data shape:  (9813, 3)
# Test data shape:  (9813, 3)

# %%
# Select n% of data
train_data = train_data.sample(frac=train_data_percentage/100, random_state=42)
valid_data = valid_data.sample(frac=valid_data_percentage/100, random_state=42)
test_data = test_data.sample(frac=test_data_percentage/100, random_state=42)

# %%
from datasets import Dataset, DatasetDict

# Convert DataFrame to Hugging Face dataset dictionary format
train_data_dict = Dataset.from_pandas(train_data)
valid_data_dict = Dataset.from_pandas(valid_data)
test_data_dict = Dataset.from_pandas(test_data)

dataset_dict = DatasetDict({
    'train': train_data_dict,
    'validation': valid_data_dict,
    'test': test_data_dict
})

print(dataset_dict)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'caption', 'image_path', '__index_level_0__'],
#         num_rows: 27476
#     })
#     validation: Dataset({
#         features: ['id', 'caption', 'image_path', '__index_level_0__'],
#         num_rows: 5888
#     })
#     test: Dataset({
#         features: ['id', 'caption', 'image_path', '__index_level_0__'],
#         num_rows: 5888
#     })
# })

# %%
# from PIL import Image

# # text preprocessing step
# def tokenization_fn(captions, max_target_length):
#     """Run tokenization on captions."""
#     labels = tokenizer(captions, 
#                       padding="max_length", 
#                       max_length=max_target_length).input_ids

#     return labels

# # image preprocessing step
# def preprocess_images(image_paths):
#     processed_images = []
#     for image_path in image_paths:
#         image = Image.open(image_path)
#         if image.mode != "RGB":
#             image = image.convert("RGB")
#         processed_images.append(image)
#     return processed_images

# def feature_extraction_fn(image_paths, check_image=True):
#     if check_image:
#         images = preprocess_images(image_paths)
#     else:
#         images = [Image.open(image_file) for image_file in image_paths]

#     encoder_inputs = feature_extractor(images=images, return_tensors="np")

#     return encoder_inputs.pixel_values

# # def feature_extraction_fn(image_paths, check_image=True):
# #     """
# #     Run feature extraction on images
# #     If `check_image` is `True`, the examples that fails during `Image.open()` will be caught and discarded.
# #     Otherwise, an exception will be thrown.
# #     """
# #     model_inputs = {}

# #     if check_image:
# #         images = []
# #         to_keep = []
# #         for image_file in image_paths:
# #             try:
# #                 img = Image.open(image_file)
# #                 images.append(img)
# #                 to_keep.append(True)
# #             except Exception:
# #                 to_keep.append(False)
# #     else:
# #         images = [Image.open(image_file) for image_file in image_paths]

# #     encoder_inputs = feature_extractor(images=images, return_tensors="np")

# #     return encoder_inputs.pixel_values

# def preprocess_fn(examples, max_target_length, check_image = True):
#     """Run tokenization + image feature extraction"""
#     image_paths = examples['image_path']
#     captions = examples['caption']    
    
#     model_inputs = {}
#     # This contains image path column
#     model_inputs['labels'] = tokenization_fn(captions, max_target_length)
#     model_inputs['pixel_values'] = feature_extraction_fn(image_paths, check_image=check_image)

#     return model_inputs

# %%
class ImageCapatioingDataset(torch.utils.data.Dataset):
    def __init__(self, ds, ds_type, max_target_length):
        self.ds = ds
        self.max_target_length = max_target_length
        self.ds_type = ds_type

    def __getitem__(self, idx):
        image_path = self.ds[self.ds_type]['image_path'][idx]
        caption = self.ds[self.ds_type]['caption'][idx]
        model_inputs = dict()
        model_inputs['labels'] = self.tokenization_fn(caption, self.max_target_length)
        model_inputs['pixel_values'] = self.feature_extraction_fn(image_path)
        return model_inputs

    def __len__(self):
        return len(self.ds[self.ds_type])
    
    # text preprocessing step
    def tokenization_fn(self, caption, max_target_length):
        """Run tokenization on caption."""
        labels = tokenizer(caption, 
                          padding="max_length", 
                          max_length=max_target_length,
                          truncation=True).input_ids

        return labels

    # image preprocessing step
    def feature_extraction_fn(self, image_path):
        image = Image.open(image_path)
        if image.mode != "RGB":
            image = image.convert("RGB")

        encoder_inputs = feature_extractor(images=image, return_tensors="np")

        return encoder_inputs.pixel_values[0]
#         except Exception:
#             print(Exception)
#             return np.empty((0,))

# %%
# processed_dataset = dataset_dict.map(
#     function=preprocess_fn,
#     batched=True,
#     fn_kwargs={"max_target_length": 128},
#     remove_columns=dataset_dict['train'].column_names
# )

# %%
# processed_dataset

# %%
train_ds = ImageCapatioingDataset(dataset_dict, 'train', max_target_length)
eval_ds = ImageCapatioingDataset(dataset_dict, 'validation', max_target_length)
test_ds = ImageCapatioingDataset(dataset_dict, 'test', max_target_length)

# %% [markdown]
# ## Define seq2seq training argumentsPermalink

# %%
from transformers import Seq2SeqTrainer, Seq2SeqTrainingArguments

training_args = Seq2SeqTrainingArguments(
    predict_with_generate=True,
    evaluation_strategy="epoch",
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    output_dir="./image-captioning-output",
)
# Out:
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).

# %% [markdown]
# ## Define metric

# %%
import evaluate
metric = evaluate.load("rouge")

# %%
import numpy as np

ignore_pad_token_for_loss = True

def postprocess_text(preds, labels):
    preds = [pred.strip() for pred in preds]
    labels = [label.strip() for label in labels]

    # rougeLSum expects newline after each sentence
    preds = ["\n".join(nltk.sent_tokenize(pred)) for pred in preds]
    labels = ["\n".join(nltk.sent_tokenize(label)) for label in labels]

    return preds, labels

def compute_metrics(eval_preds):
    preds, labels = eval_preds
    if isinstance(preds, tuple):
        preds = preds[0]
    decoded_preds = tokenizer.batch_decode(preds, skip_special_tokens=True)
    if ignore_pad_token_for_loss:
        # Replace -100 in the labels as we can't decode them.
        labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    # Some simple post-processing
    decoded_preds, decoded_labels = postprocess_text(decoded_preds,
                                                     decoded_labels)

    result = metric.compute(predictions=decoded_preds,
                            references=decoded_labels,
                            use_stemmer=True)
    result = {k: round(v * 100, 4) for k, v in result.items()}
    prediction_lens = [
        np.count_nonzero(pred != tokenizer.pad_token_id) for pred in preds
    ]
    result["gen_len"] = np.mean(prediction_lens)
    return result

# %% [markdown]
# ## Training

# %%
from transformers import default_data_collator

# # instantiate trainer
# trainer = Seq2SeqTrainer(
#     model=model,
#     tokenizer=feature_extractor,
#     args=training_args,
#     compute_metrics=compute_metrics,
#     train_dataset=processed_dataset['train'],
#     eval_dataset=processed_dataset['validation'],
#     data_collator=default_data_collator,
# )

# instantiate trainer
trainer = Seq2SeqTrainer(
    model=model,
    tokenizer=feature_extractor,
    args=training_args,
    compute_metrics=compute_metrics,
    train_dataset=train_ds,
    eval_dataset=eval_ds,
    data_collator=default_data_collator,
)

#6799

# %%
#trainer.train()

# %%
trainer.train("./image-captioning-output\checkpoint-6500")
# Out:
# Loading model from ./image-captioning-output\checkpoint-6500.
# C:\Users\ACER\anaconda3\lib\site-packages\transformers\optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 27476
#   Num Epochs = 3
#   Instantaneous batch size per device = 4
#   Total train batch size (w. parallel, distributed & accumulation) = 4
#   Gradient Accumulation steps = 1
#   Total optimization steps = 20607
#   Number of trainable parameters = 239195904
#   Continuing training from checkpoint, will skip to saved global_step
#   Continuing training from epoch 0
#   Continuing training from global step 6500
#   Will skip the first 0 epochs then the first 6500 batches in the first epoch. If this takes a lot of time, you can add the `--ignore_data_skip` flag to your launch command, but you will resume the training on data already seen by your model.
#   0%|          | 0/6500 [00:00<?, ?it/s]
#     <div>
#
#       <progress value='14501' max='20607' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [14501/20607 3:07:21 < 2:23:01, 0.71 it/s, Epoch 2.11/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.402100</td>
#       <td>0.379527</td>
#       <td>20.913500</td>
#       <td>5.659200</td>
#       <td>18.177300</td>
#       <td>18.565500</td>
#       <td>17.566576</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.365700</td>
#       <td>0.362218</td>
#       <td>21.679100</td>
#       <td>6.657100</td>
#       <td>19.303200</td>
#       <td>19.594900</td>
#       <td>16.492867</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='1472' max='1472' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1472/1472 26:00]
#     </div>
# ***** Running Evaluation *****
#   Num examples = 5888
#   Batch size = 4
# Saving model checkpoint to ./image-captioning-output\checkpoint-7000
# Configuration saved in ./image-captioning-output\checkpoint-7000\config.json
# Model weights saved in ./image-captioning-output\checkpoint-7000\pytorch_model.bin
# Feature extractor saved in ./image-captioning-output\checkpoint-7000\preprocessor_config.json
# Saving model checkpoint to ./image-captioning-output\checkpoint-7500
# Configuration saved in ./image-captioning-output\checkpoint-7500\config.json
# Model weights saved in ./image-captioning-output\checkpoint-7500\pytorch_model.bin
# Feature extractor saved in ./image-captioning-output\checkpoint-7500\preprocessor_config.json
# Saving model checkpoint to ./image-captioning-output\checkpoint-8000
# Configuration saved in ./image-captioning-output\checkpoint-8000\config.json
# Model weights saved in ./image-captioning-output\checkpoint-8000\pytorch_model.bin
# Feature extractor saved in ./image-captioning-output\checkpoint-8000\preprocessor_config.json
# Saving model checkpoint to ./image-captioning-output\checkpoint-8500
# Configuration saved in ./image-captioning-output\checkpoint-8500\config.json
# Model weights saved in ./image-captioning-output\checkpoint-8500\pytorch_model.bin
# Feature extractor saved in ./image-captioning-output\checkpoint-8500\preprocessor_config.json
# Saving model checkpoint to ./image-captioning-output\checkpoint-9000
# Configuration saved in ./image-captioning-output\checkpoint-9000\config.json
# Model weights saved in ./image-captioning-output\checkpoint-9000\pytorch_model.bin
# Feature extractor saved in ./image-captioning-output\checkpoint-9000\preprocessor_config.json
# Saving model checkpoint to ./image-captioning-output\checkpoint-9500
# Configuration saved in ./image-captioning-output\checkpoint-9500\config.json
# Model weights saved in ./image-captioning-output\checkpoint-9500\pytorch_model.bin
# Feature extractor saved in ./image-captioning-output\checkpoint-9500\preprocessor_config.json
# Saving model checkpoint to ./image-captioning-output\checkpoint-10000
# Configuration saved in ./image-captioning-output\checkpoint-10000\config.json
# Model weights saved in ./image-captioning-output\checkpoint-10000\pytorch_model.bin
# Feature extractor saved in ./image-captioning-output\checkpoint-10000\preprocessor_config.json
# Saving model checkpoint to ./image-captioning-output\checkpoint-10500
# Configuration saved in ./image-captioning-output\checkpoint-10500\config.json
# Model weights saved in ./image-captioning-output\checkpoint-10500\pytorch_model.bin
# Feature extractor saved in ./image-captioning-output\checkpoint-10500\preprocessor_config.json
# Saving model checkpoint to ./image-captioning-output\checkpoint-11000
# Configuration saved in ./image-captioning-output\checkpoint-11000\config.json
# Model weights saved in ./image-captioning-output\checkpoint-11000\pytorch_model.bin
# Feature extractor saved in ./image-captioning-output\checkpoint-11000\preprocessor_config.json
# Saving model checkpoint to ./image-captioning-output\checkpoint-11500
# Configuration saved in ./image-captioning-output\checkpoint-11500\config.json
# Model weights saved in ./image-captioning-output\checkpoint-11500\pytorch_model.bin
# Feature extractor saved in ./image-captioning-output\checkpoint-11500\preprocessor_config.json
# Saving model checkpoint to ./image-captioning-output\checkpoint-12000
# Configuration saved in ./image-captioning-output\checkpoint-12000\config.json
# Model weights saved in ./image-captioning-output\checkpoint-12000\pytorch_model.bin
# Feature extractor saved in ./image-captioning-output\checkpoint-12000\preprocessor_config.json
# Saving model checkpoint to ./image-captioning-output\checkpoint-12500
# Configuration saved in ./image-captioning-output\checkpoint-12500\config.json
# Model weights saved in ./image-captioning-output\checkpoint-12500\pytorch_model.bin
# Feature extractor saved in ./image-captioning-output\checkpoint-12500\preprocessor_config.json
# Saving model checkpoint to ./image-captioning-output\checkpoint-13000
# Configuration saved in ./image-captioning-output\checkpoint-13000\config.json
# Model weights saved in ./image-captioning-output\checkpoint-13000\pytorch_model.bin
# Feature extractor saved in ./image-captioning-output\checkpoint-13000\preprocessor_config.json
# Saving model checkpoint to ./image-captioning-output\checkpoint-13500
# Configuration saved in ./image-captioning-output\checkpoint-13500\config.json
# Model weights saved in ./image-captioning-output\checkpoint-13500\pytorch_model.bin
# Feature extractor saved in ./image-captioning-output\checkpoint-13500\preprocessor_config.json
# ***** Running Evaluation *****
#   Num examples = 5888
#   Batch size = 4
# Saving model checkpoint to ./image-captioning-output\checkpoint-14000
# Configuration saved in ./image-captioning-output\checkpoint-14000\config.json
# Model weights saved in ./image-captioning-output\checkpoint-14000\pytorch_model.bin
# Feature extractor saved in ./image-captioning-output\checkpoint-14000\preprocessor_config.json
# Saving model checkpoint to ./image-captioning-output\checkpoint-14500
# Configuration saved in ./image-captioning-output\checkpoint-14500\config.json
# Model weights saved in ./image-captioning-output\checkpoint-14500\pytorch_model.bin
# Feature extractor saved in ./image-captioning-output\checkpoint-14500\preprocessor_config.json
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\torch\serialization.py:441, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     440 with _open_zipfile_writer(f) as opened_zipfile:
# --> 441     _save(obj, opened_zipfile, pickle_module, pickle_protocol)
#     442     return
#
# File ~\anaconda3\lib\site-packages\torch\serialization.py:668, in _save(obj, zip_file, pickle_module, pickle_protocol)
#     667 num_bytes = storage.nbytes()
# --> 668 zip_file.write_record(name, storage.data_ptr(), num_bytes)
#
# RuntimeError: [enforce fail at ..\caffe2\serialize\inline_container.cc:476] . PytorchStreamWriter failed writing file data/179: file write failed
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 trainer.train("./image-captioning-output\checkpoint-6500")
#
# File ~\anaconda3\lib\site-packages\transformers\trainer.py:1501, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1496     self.model_wrapped = self.model
#    1498 inner_training_loop = find_executable_batch_size(
#    1499     self._inner_training_loop, self._train_batch_size, args.auto_find_batch_size
#    1500 )
# -> 1501 return inner_training_loop(
#    1502     args=args,
#    1503     resume_from_checkpoint=resume_from_checkpoint,
#    1504     trial=trial,
#    1505     ignore_keys_for_eval=ignore_keys_for_eval,
#    1506 )
#
# File ~\anaconda3\lib\site-packages\transformers\trainer.py:1826, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1823     self.state.epoch = epoch + (step + 1) / steps_in_epoch
#    1824     self.control = self.callback_handler.on_step_end(args, self.state, self.control)
# -> 1826     self._maybe_log_save_evaluate(tr_loss, model, trial, epoch, ignore_keys_for_eval)
#    1827 else:
#    1828     self.control = self.callback_handler.on_substep_end(args, self.state, self.control)
#
# File ~\anaconda3\lib\site-packages\transformers\trainer.py:2093, in Trainer._maybe_log_save_evaluate(self, tr_loss, model, trial, epoch, ignore_keys_for_eval)
#    2090     self._report_to_hp_search(trial, self.state.global_step, metrics)
#    2092 if self.control.should_save:
# -> 2093     self._save_checkpoint(model, trial, metrics=metrics)
#    2094     self.control = self.callback_handler.on_save(self.args, self.state, self.control)
#
# File ~\anaconda3\lib\site-packages\transformers\trainer.py:2184, in Trainer._save_checkpoint(self, model, trial, metrics)
#    2181             torch.save(self.scaler.state_dict(), os.path.join(output_dir, SCALER_NAME))
#    2182 elif self.args.should_save and not self.deepspeed:
#    2183     # deepspeed.save_checkpoint above saves model/optim/sched
# -> 2184     torch.save(self.optimizer.state_dict(), os.path.join(output_dir, OPTIMIZER_NAME))
#    2185     with warnings.catch_warnings(record=True) as caught_warnings:
#    2186         torch.save(self.lr_scheduler.state_dict(), os.path.join(output_dir, SCHEDULER_NAME))
#
# File ~\anaconda3\lib\site-packages\torch\serialization.py:440, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     437 _check_save_filelike(f)
#     439 if _use_new_zipfile_serialization:
# --> 440     with _open_zipfile_writer(f) as opened_zipfile:
#     441         _save(obj, opened_zipfile, pickle_module, pickle_protocol)
#     442         return
#
# File ~\anaconda3\lib\site-packages\torch\serialization.py:291, in _open_zipfile_writer_file.__exit__(self, *args)
#     290 def __exit__(self, *args) -> None:
# --> 291     self.file_like.write_end_of_file()
#
# RuntimeError: [enforce fail at ..\caffe2\serialize\inline_container.cc:337] . unexpected pos 730413952 vs 730413840

# %%
`

# %%
trainer.save_model("./image-captioning-output")
tokenizer.save_pretrained("./image-captioning-output")

# %%
# Get predictions from the model
predictions = trainer.predict(test_ds)

# Process and evaluate the predictions
preds = predictions.predictions
labels = predictions.label_ids

# Post-process the predictions and labels
decoded_preds = tokenizer.batch_decode(preds, skip_special_tokens=True)
decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

# Calculate evaluation metrics
from nltk.translate.bleu_score import sentence_bleu, corpus_bleu
bleu_scores = []

# Print the actual captions and predicted captions
i = 0
for actual_caption, predicted_caption in zip(decoded_labels, decoded_preds):
    i += 1
    bleu_score = sentence_bleu([actual_caption.split()], predicted_caption.split())
    bleu_scores.append(bleu_score)
    if i % 20 == 0:
        print("Actual Caption:", actual_caption)
        print("Predicted Caption:", predicted_caption)
        print("Blue score: ", bleu_score)
        print("--------------")

average_bleu_score = sum(bleu_scores) / len(bleu_scores)

# Print average BLEU score
print("Average BLEU score:", average_bleu_score)
# Out:
# ***** Running Prediction *****
#   Num examples = 5888
#   Batch size = 4
# C:\Users\ACER\anaconda3\lib\site-packages\nltk\translate\bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# C:\Users\ACER\anaconda3\lib\site-packages\nltk\translate\bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# C:\Users\ACER\anaconda3\lib\site-packages\nltk\translate\bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Actual Caption:  Vascular anatomic variants. The coronal multiplanar reformatted image demonstrates the origin of the right hepatic artery (black arrow) from the superior mesenteric artery (white arrow) and diffuse telangiectasias (black arrowheads) in the peripheral parenchyma.
#
# Predicted Caption:  Coronal CT angiography showing a large right common carotid artery (arrow) and
# Blue score:  2.0596184594894264e-232
# --------------
# Actual Caption:  Identification of anastomosis site by duplex scan. The extent of calcification is easily estimated by the thickness and intensity of echo density. The figure shows the calcified tibial artery, which is not suitable as a distal anastomosis site.
#
# Predicted Caption:  Ultrasound image of the right breast showing a hypoechoic mass with a hypoe
# Blue score:  1.8455299742220844e-232
# --------------
# Actual Caption:  White line: posterior condylar line. Red line: anatomical transepicondylar axis.
#
# Predicted Caption:  Axial T2-weighted image of the knee joint showing the medial aspect of the fem
# Blue score:  0
# --------------
# Actual Caption:  Cropped panoramic image showing measurements on the mandibular right first molar
#
# Predicted Caption:  Panoramic radiograph of the patient showing the radiolucent area of the maxillary
# Blue score:  1.1640469867513693e-231
# --------------
# Actual Caption:  Initial dental X-ray (arrow, lesion with root-like radiopacity).
#
# Predicted Caption:  Postoperative radiograph showing the implant placement.
#
# Blue score:  0
# --------------
# Actual Caption:  Parasternal transverse view at the level of the mitral valve leaflets. Visible open, nearly circular valve orifice located eccentrically – above the posteromedial papillary muscle. It is not possible to differentiate the commissures. The cross-section at this level does not show abnormal structures connected with the valve leaflets. LK – left ventricle, PK – right ventricle, # – aortic leaflet, ^^ – mural leaflet
#
# Predicted Caption:  Transesophageal echocardiography showing a large mass in the left atrium
# Blue score:  5.50269726200703e-234
# --------------
# Actual Caption:  Preoperative intraoral periapical radiograph
#
# Predicted Caption:  Preoperative radiograph
#
# Blue score:  6.702145341854094e-232
# --------------
# Actual Caption:  Axial Gadolinium-enhanced T1-weighted MRI showing no lesion enhancement.
#
# Predicted Caption:  Axial T1-weighted image shows a hyperintense lesion in the left par
# Blue score:  1.3165594234639305e-231
# --------------
# Actual Caption:  CTA demonstrated a right-sided aortic arch and a right descending thoracic aorta, a type B aortic.
#
# Predicted Caption:  CT scan of the chest showing a large mass in the right upper lobe.
#
# Blue score:  9.709385502639237e-232
# --------------
# Actual Caption:  Thyroid ultrasound revealed a 14x14x22 mm nodule with a mixed echo pattern, rough calcification foci and cystic-necrotic areas in the left lobe lower pole. Fine needle aspiration biopsy of this nodule complied with benign follicular nodule. Bone scintigraphy is usually performed to evaluate a wide variety of skeletal abnormalities (1). Tc-99m-labeled diphosphonates have been used for bone scanning as a major diagnostic tool since the beginning of 1970s (2). Tc-99m MDP has rapid blood clearance, excellent in vivo chemical stability, and a high bone-to-soft tissue ratio, thus, it is ideal for bone imaging (3). In the literature, many cases of incidental Tc-99m-MDP uptake by the soft tissue have been reported due to various reasons, both benign (tumoral calcinosis, myositis ossificans) and malignant (sarcomas, adenocarcinomas, metastases) conditions (4,5). Mechanisms leading to increased extraosseous Tc-99m MDP uptake include extracellular fluid expansion, enhanced local vascularity and permeability, and high tissue calcium
# Predicted Caption:  Ultrasound image of the right breast showing a hypoechoic mass with a hypoe
# Blue score:  1.9505289878391747e-159
# --------------
# Actual Caption:  Abdominal computed tomography (CT) revealed fluid accumulation in the paracolic gutter on the right side.
#
# Predicted Caption:  CT scan of the abdomen and pelvis showing a large mass in the right iliac foss
# Blue score:  6.373704167435469e-155
# --------------
# Actual Caption:  Axial 2 mm MIP at the level of C1.The left vertebral artery is normal. No wall can be identified as is the usual situation. On the right, there is irregular tapered occlusion of the V3 dissected segment. There is also evidence of vessel wall thickening
#
# Predicted Caption:  Axial CT scan of the neck showing the fracture of the right maxillary sinus.
#
# Blue score:  6.942887277283473e-156
# --------------
# Actual Caption:  Pathline visualization of cardiac blood flow using 4D phase contrast MRI. Pathlines are originated from planes at the mitral valve (red-yellow) and the tricuspid valve (blue-turquoise) at early diastolic ventricular inflow. A separately acquired balanced steady-state free precession three-chamber image was superimposed for providing anatomical orientation [67].
#
# Predicted Caption:  The image of the left ventricle in a patient with a history of pulmonary embolism
# Blue score:  1.4430152730626161e-232
# --------------
# Actual Caption:  AP pelvis X-ray showing avascular changes of subchondral cystic lucency without evidence of femoral head collapse.
#
# Predicted Caption:  Postoperative radiograph of the pelvis showing the reduction of the fracture.
#
# Blue score:  8.979839354996391e-232
# --------------
# Actual Caption:   Plain film imaging after the second embolization demonstrating the platinum coils used for endovascular embolization of feeding arteries to the rapidly involuting congenital hemangiomas.
#
# Predicted Caption:  A lateral view of the pelvis shows a large cystic lesion in the left femoral
# Blue score:  6.686350417856737e-232
# --------------
# Actual Caption:  Case 15 (2 years duration of diabetes mellitus).Average subepidermal capillary basement membrane thickness on electron micrograph measuring 2.5 mm in length, calculating 2,300 Å with normogram (×11,000).
#
# Predicted Caption:  A representative image of the same patient as in Fig. 1. The image shows the same
# Blue score:  5.447012482354515e-232
# --------------
# Actual Caption:  Pre-endoscopic treatment; 40 mm coronal MIP reformat of MRCP. The common bile duct runs to the major papilla. The pancreatic duct drains through the minor papilla (arrow).
#
# Predicted Caption:  Magnetic resonance cholangiopancreatography (MRCP) of the patient showing a
# Blue score:  1.692841243110689e-232
# --------------
# Actual Caption:  Midsagittal slice of a magnetic resonance image from a normal subject. Note the maxillomandibular relationship, the symmetry of the palate, and the diameter of the air passage.
#
# Predicted Caption:  Sagittal T2-weighted MRI of the cervical spine showing a large mass in the posterior
# Blue score:  2.269320932099131e-155
# --------------
# Actual Caption:  Mid-esophageal stricture found on EGD.
#
# Predicted Caption:  Chest X-ray showing a large right-sided pleural effusion
#
# Blue score:  0
# --------------
# Actual Caption:  Lobar consolidation involving the right middle lobe, right lower lobe and left lower lobe.
#
# Predicted Caption:  Chest X-ray showing a large right-sided pleural effusion.
#
# Blue score:  0
# --------------
# Actual Caption:  3D volumetric quantification of femoral areas with regards to the localization scheme using the customized software
#
# Predicted Caption:  The distance between the lateral and lateral lines of the lateral and lateral lines of the lateral and lateral
# Blue score:  1.1484186507842885e-231
# --------------
# Actual Caption:  Post-treatment MRI of the brain with and without contrast. Postoperative changes in the right frontotemporoparietal region are shown. Irregular enhancement at the surgical site extends to the walls of the right lateral ventricle. This was unchanged in subsequent MRI scans.
#
# Predicted Caption:  Axial T2-weighted image of the brain showing a hyperintense lesion in
# Blue score:  2.6226577886378133e-79
# --------------
# Actual Caption:  Modified apical 4-chamber view (posterior angulation) showing the stomach (arrowhead) above the left ventricle in the thorax outside of the pericardium.
#
# Predicted Caption:  Transesophageal echocardiography showing a large mass in the left atrium
# Blue score:  2.7111912549619096e-155
# --------------
# Actual Caption:  Master-cone radiograph
#
# Predicted Caption:  Postoperative radiograph
#
# Blue score:  1.5319719891192393e-231
# --------------
# Actual Caption:  Epididymal cyst in a 32-year-old male with scrotal pain.Gray-scale ultrasonogram shows a well-circumscribed anechoic lesion (asterisk) in the epididymal head that does not demonstrate internal vascularity.
#
# Predicted Caption:  Ultrasound image of the left testis. The arrow indicates the testis.
#
# Blue score:  2.558234810691267e-232
# --------------
# Actual Caption:  A 12-year-old boy, NMR examination performed 6 weeks after trauma. T1W sequence, coronal plane, posttraumatic bone marrow edema, attenuated signal detected within scaphoid and capitate bones.
#
# Predicted Caption:  Magnetic resonance imaging of the spine showing a mass in the posterior aspect of the left paraspinal
# Blue score:  0
# --------------
# Actual Caption:  Dorsomedial palmarolateral 45° oblique radiographic image of the metacarpophalangeal joint of case 1. Periosteal osteoproliferation is visible at the mid-palmaromedial surface of the proximal phalanx (arrowheads).
#
# Predicted Caption:  Radiograph of the right knee showing a large osteolytic lesion (arrow) in
# Blue score:  1.6297062694222344e-155
# --------------
# Actual Caption:  Contrast-enhanced CT, sagittal oblique reconstruction showing a right femoral hernia containing the appendix. The appendix is well seen from its origin at the base of the caecum, going down towards the hernia. Fluid effusion is also seen along the herniated sac.
#
# Predicted Caption:  CT scan of the abdomen and pelvis showing a large mass in the right iliac foss
# Blue score:  1.478528120222825e-155
# --------------
# Actual Caption:  Periapical radiograph of the right maxillary second and third premolars sealed with MTA showing absence of periodontal lesion in the perforation region
#
# Predicted Caption:  Preoperative radiograph of the maxilla
#
# Blue score:  2.2921069044961154e-79
# --------------
# Actual Caption:  Stent in common bile duct.
#
# Predicted Caption:  Fluoroscopic image of the left renal artery.
#
# Blue score:  0
# --------------
# Actual Caption:  Bone erosion of left malar bone is identified in the computed tomography scan with extension to the lateral orbital rim, zygomatic arch and ipsilateral palate, associated with edema of preseptal soft tissue, the presence of small subperiosteal collection upper outer margin, with occupation of the maxillary sinus, without enhancement after contrast administration.
#
# Predicted Caption:  Axial CT scan of the head showing a large mass in the right orbit with a central nec
# Blue score:  1.0039293457307022e-155
# --------------
# Actual Caption:  Demonstration of the technique to measure a single vertical pocket of liquor. Hydramnios is present in this case
#
# Predicted Caption:  Ultrasound image of the right kidney. The arrow indicates the renal vein.
#
# Blue score:  3.1742343778739085e-155
# --------------
# Actual Caption:  Sagittal magnetic resonance image demonstrating a pedicle of the tumor attached to the uterine fundus, extrusion of the tumor into the vagina (star), and concavity of the uterine fundus (arrow).
#
# Predicted Caption:  Sagittal T2-weighted MRI of the pelvis showing a large mass (arrow)
# Blue score:  1.1579612543774053e-155
# --------------
# Actual Caption:  37-year-old woman with intrauterine pregnancy and right tubal pregnancy, following surgical excision of the right tubal pregnancy. Follow-up transvaginal ultrasound demonstrates continued appropriate growth of the intrauterine gestation now measuring 2 cm corresponding to a gestational age of 8 weeks 4 days.
#
# Predicted Caption:  Transverse view of the abdomen and pelvis showing a large mass in the right upper quadrant
# Blue score:  1.388948629874375e-155
# --------------
# Actual Caption:  X-ray skull showing break in continuity of inner skull margin
#
# Predicted Caption:  Fluorescein angiography of the left eye showing the presence of a hypodense
# Blue score:  1.1640469867513693e-231
# --------------
# Actual Caption:  Coronal short tau inversion recovery magnetic resonance imaging reveals a multiloculated, hyperintense fluid collection in the soft tissue lateral to the mandible and zygomatic arch (arrow). Note the separate hypointense collection in the masticator space anterior to the mandibular condyle (double arrow). This is turbulent flow within the pseudoaneurysm.
#
# Predicted Caption:  Axial T1-weighted image shows a hyperintense lesion in the left orbit
# Blue score:  2.0584911958095165e-156
# --------------
# Actual Caption:  TVU image: irregular liquid dark area in the myometrium of lower uterine (arrow).
#
# Predicted Caption:  Ultrasound image of the left ovary.
#
# Blue score:  4.310732902257592e-232
# --------------
# Actual Caption:   A post-embolization venogram showing the retention of contrast medium upstream of the coils.
#
# Predicted Caption:  Abdominal X-ray showing a large bowel obstruction.
#
# Blue score:  4.753148692240233e-232
# --------------
# Actual Caption:  Postoperative CT scan (four months p.o), showing the liver graft with the patent Dacron prosthesis (arrow).
#
# Predicted Caption:  CT scan of the abdomen showing a large mass in the right lobe of the liver.
#
# Blue score:  5.667113443314699e-155
# --------------
# Actual Caption:  CT abdomen following contrast media administration. A tumor of the jejunum (white arrow)
#
# Predicted Caption:  CT scan of the abdomen and pelvis showing a large mass in the right iliac foss
# Blue score:  5.359624986283916e-155
# --------------
# Actual Caption:  Coronal SSFSE T2-W image in a gestational week 26 fetus demonstrates several hypointense nodules along the margins of both lateral ventricles (arrows), consistent with subependymal nodules; these are indistinguishable from periventricular nodular heterotopia (see Fig. 1). A hypointense wedge-shaped area is seen extending from the margin of the left lateral ventricle to the developing cortex (arrowhead), consistent with transmantle dysplasia. Findings are consistent with tuberous sclerosis. (Reprinted with permission [2])
#
# Predicted Caption:  T2-weighted axial MRI of the brain showing a large mass (arrow) in
# Blue score:  4.9539741360560546e-157
# --------------
# Actual Caption:  – Abdominal computed tomography (CT) – portal phase – coronal reformatted image showing a huge mass occupying half of the abdominal volume, crossing the midline, predominantly composed of adipose tissue interspersed with multiple vascular structures. The right kidney is displaced medially. Note the relationship of the mass with the renal parenchyma at its lower pole.
#
# Predicted Caption:  CT scan of abdomen and pelvis showing a large mass in the right iliac fossa
# Blue score:  4.261245800242269e-156
# --------------
# Actual Caption:  CT scan of causative upper right quadrant mass (indicated with dashed line). Scale = 5 cm
#
# Predicted Caption:  CT scan of the abdomen showing a large mass in the right kidney.
#
# Blue score:  2.679075689180148e-78
# --------------
# Actual Caption:  Radiograph 5 months after surgery. Bone union of the dorsal epiphysis was achieved.
#
# Predicted Caption:  Radiograph of the right hand showing a large osteolytic lesion in the distal
# Blue score:  5.554837769749797e-155
# --------------
# Actual Caption:  Postoperative computed tomography scan
#
# Predicted Caption:  Computed tomography scan showing a large mass in the right orbit
#
# Blue score:  5.477489369001354e-155
# --------------
# Actual Caption:  An example of IMRT plan showing the dose distribution at one of the CT slices. The plan was computed based on the PTVCM (Red). The black arrows indicate the regions of PTVCMP (Cyan) receiving less than 95 % isodose level (indicated by the red arrow)
#
# Predicted Caption:  CT scan of the patient’s right shoulder. The arrow indicates the location of the needle
# Blue score:  8.62587058766258e-156
# --------------
# Actual Caption:  The guide wire and catheter were entered into the popliteal vein.
#
# Predicted Caption:  Angiography of the left internal carotid artery showing a large pseudoaneurysm
# Blue score:  1.0003688322288243e-231
# --------------
# Actual Caption:  Fluoroscopic upper gastrointestinal contrast study. Narrowing and shouldering at the pylorus (arrows) consistent with hypertrophic pyloric stenosis.
#
# Predicted Caption:  Intraoperative cholangiography showing a large cystic lesion in the left hep
# Blue score:  5.797920459331518e-232
# --------------
# Actual Caption:   Classical asymmetrical temporal lobe T2 hyperintensity in a patient with Herpes Simplex Virus type-1 encephalitis.
#
# Predicted Caption:  T2-weighted image of the brain showing hyperintense signal in the right parietal
# Blue score:  7.623236468879228e-232
# --------------
# Actual Caption:  The patient's left coronary angiography.
#
# Predicted Caption:  Coronary angiography showing a large left anterior descending artery (LAO) arising from
# Blue score:  9.788429383461836e-232
# --------------
# Actual Caption:  Angiogram of the brachiocephalic artery shows the hypertrophic aberrant bronchial artery (white arrow) arising from the proximal portion of the right internal mammary artery (black arrow), findings that corresponded with the CTA image.
#
# Predicted Caption:  Angiography of the left internal carotid artery.
#
# Blue score:  1.8795176866057151e-156
# --------------
# Actual Caption:  CT abdomen showing large air-filled right abdominal mass that appears to be a septic ovarian cyst.
#
# Predicted Caption:  CT scan of the abdomen and pelvis showing a large mass in the right iliac foss
# Blue score:  1.4816746066915526e-231
# --------------
# Actual Caption:  Fluid-filled left thoracic cavity in keeping with a left pneumonectomy. A right-sided mass lesion is seen.
#
# Predicted Caption:  CT scan of the chest showing a large mass in the right upper lobe (arrow).
#
# Blue score:  1.1397585453531419e-231
# --------------
# Actual Caption:  Lateral radiograph of the knee demonstrating the area of calcium phosphate bone cementage in the medial femoral and medial tibial condyles.
#
# Predicted Caption:  Anteroposterior radiograph of the pelvis showing a fracture of the femoral head
# Blue score:  1.7814230817596996e-78
# --------------
# Actual Caption:  Spiral CT after administration of oral and intravenous contrast. Five-millimeter sections were obtained. The white arrow shows the fistula tract on the anterior wall of the abdomen.
#
# Predicted Caption:  CT scan of the abdomen and pelvis showing a large mass in the right iliac foss
# Blue score:  2.8496035952422627e-155
# --------------
# Actual Caption:  The same patient as in Fig. (2); after implantation of a Roseland prosthesis (Depuy Int. Ltd., Leeds, England).
#
# Predicted Caption:  Radiograph of the right hand showing a large lytic lesion in the left hand.
# Blue score:  9.314777610904016e-232
# --------------
# Actual Caption:  Follow-up computed tomographic scan shows no evidence of recurrence.
#
# Predicted Caption:  CT scan of the chest showing a large mass in the right upper lobe.
#
# Blue score:  1.1200407237786664e-231
# --------------
# Actual Caption:  A solid mass (white arrow) 35 × 37 mm in diameter was identified in the left adrenal region in magnetic resonance imaging.
#
# Predicted Caption:  Magnetic resonance imaging of the abdomen and pelvis showing a large mass in the right adrenal gland
# Blue score:  4.0929724333715126e-155
# --------------
# Actual Caption:  Six-inch metallic object: artery forceps in the right lower quadrant of abdomen.
#
# Predicted Caption:  Plain abdominal radiograph showing a large mass in the right upper quadrant of the abdomen.
#
# Blue score:  3.480275084383042e-78
# --------------
# Actual Caption:  Skull radiograph—multiple lytic areas.
#
# Predicted Caption:  Postoperative lateral cephalogram showing the correct position of the screws.
#
# Blue score:  0
# --------------
# Actual Caption:  T2-weighted axial MRI comparable in position and image acquisition to Figure 4 demonstrating complete resolution of IVC thrombosis (white arrow) after 4 months of oral anticoagulation therapy
#
# Predicted Caption:  Axial T2-weighted image of the liver shows a large heterogeneous mass in the
# Blue score:  4.6220616466129664e-232
# --------------
# Actual Caption:  Horizontal computed tomography scans showed a large bilateral hemothorax; fractures of bilateral pedicles of vertebral arch.
#
# Predicted Caption:  CT scan of the chest showing a large mass in the right upper lobe.
#
# Blue score:  4.63332339029038e-155
# --------------
# Actual Caption:  Follow-up CT after surgery. MPR reconstruction.
#
# Predicted Caption:  Sagittal CT scan of the cervical spine showing a large mass in the C2-C3
# Blue score:  9.418382295637229e-232
# --------------
# Actual Caption:   A sagittal image: the needle reached the spinal cord. The red line 1 indicates the subarachnoid; the red line 2 indicates the spinal cord; the red line 3 indicates the needle.
#
# Predicted Caption:  Sagittal T2-weighted image of the cervical spine shows the cervical spine (C3
# Blue score:  2.3896680731711377e-232
# --------------
# Actual Caption:  MRI examination of the brain. Axial FLAIR T2 at day 5 after completing IVIg
#
# Predicted Caption:  Axial T2-weighted image shows hyperintense signal in the right parietal lobe
# Blue score:  9.056777564992551e-232
# --------------
# Actual Caption:  Preoperative intraoral periapical
#
# Predicted Caption:  Preoperative radiograph
#
# Blue score:  9.291879812217675e-232
# --------------
# Actual Caption:  Coronal T2W MR showing the previous infarctions mentioned in Figure1, in addition to another old left frontal cortical infarct
#
# Predicted Caption:  Axial T2-weighted image shows a hyperintense lesion in the left orbit
# Blue score:  6.361945342945876e-232
# --------------
# Actual Caption:  Radiograph showing metastatic tumour of the right distal humerus with an undisplaced pathological fracture through the large lytic area, and further lytic areas both proximal and distal to the lesion. In addition, a metastatic tumour was present at the right proximal tibia, with a pathological tibial plateau fracture of the right knee.
#
# Predicted Caption:  Radiograph of the right shoulder showing a fracture of the humeral head.
#
# Blue score:  2.1056077777645334e-79
# --------------
# Actual Caption:  Chest computed tomogram with intravenous contrast three months after admission with resolved ground glass infiltrates revealing the initial atelectasis of the left lower lobe present two months prior to admission (arrow).
#
# Predicted Caption:  CT scan of the chest showing a large mass in the right upper lobe.
#
# Blue score:  1.587000622918089e-155
# --------------
# Actual Caption:  Carotid duplex sonography performed on 1 October 2003. The floating thrombus is observed at the left internal carotid artery (arrow).
#
# Predicted Caption:  Ultrasound image of the right eye showing a hypoechoic lesion (arrow)
# Blue score:  4.413959087726801e-232
# --------------
# Actual Caption:  Measurement of intervertebral space height.The intervertebral space height (h) is determined by the distance from the midpoint of the superior endplate to the midpoint of the inferior endplate.
#
# Predicted Caption:  Lateral radiograph of the knee showing the lateral radiograph of the knee.
#
# Blue score:  2.0628584276138003e-155
# --------------
# Actual Caption:  M-mode at the level of the mitral leaflet tips; SAM is visible
#
# Predicted Caption:  Transesophageal echocardiography showing a large mass in the left atrium
# Blue score:  8.387826279040936e-232
# --------------
# Actual Caption:  A new hypodense lesion in caudate lobe of the liver suspicious for metastasis.
#
# Predicted Caption:  CT scan of the abdomen showing a large mass in the right adrenal gland.
#
# Blue score:  5.3448396730677054e-155
# --------------
# Actual Caption:  Scanner abdominal, coupe transversale
#
# Predicted Caption:  CT scan of the abdomen showing a large mass in the right iliac fossa.
#
# Blue score:  0
# --------------
# Actual Caption:  59-year-old male with perforation of the gallbladder. Findings: Axial contrast-enhanced CT image of the abdomen through the gallbladder in the delayed phase demonstrates increasing density within the gallbladder representing accumulating blood within the gallbladder. Technique: Axial CT image of the abdomen and pelvis with IV contrast performed in the delayed phase.
#
# Predicted Caption:  CT scan of the abdomen showing a large mass in the right kidney.
#
# Blue score:  2.1015935910955108e-79
# --------------
# Actual Caption:  Follow-up chest radiograph showed significant improvement in diffuse alveolar hemorrhage.
#
# Predicted Caption:  Chest X-ray showing bilateral diffuse pulmonary infiltrates.
#
# Blue score:  7.296382734947757e-232
# --------------
# Actual Caption:  Transthoracic echocardiography showed a large mass (white arrow) measuring 1.4 × 1.4 cm in the left atrium that could represent a thrombus or myxoma
#
# Predicted Caption:  Transesophageal echocardiography showing a large mass in the right atrium
# Blue score:  1.2446450973359083e-78
# --------------
# Actual Caption:  Chest X-ray on the day of discharge. There was a small heterogeneous opacity in the lower third of the right lung field
#
# Predicted Caption:  Chest X-ray showing bilateral diffuse pulmonary infiltrates.
#
# Blue score:  8.174973610061789e-156
# --------------
# Actual Caption:  Ultrasonography showed multiple homogeneously low echoic mass in liver.
#
# Predicted Caption:  Ultrasound image of the right kidney.
#
# Blue score:  0
# --------------
# Actual Caption:  Coronal PD fat sat: bone bruising within right trapezoid bone centered distally and toward palmar surface. This is associated with an undisplaced low signal fracture line
#
# Predicted Caption:  MRI of the pelvis showing a large mass in the left hip.
#
# Blue score:  0
# --------------
# Actual Caption:  On the weight-bearing dorsoplantar foot radiograph, lines were measured and drawn; line 1 is the longitudinal distance medial aspect of the proximal phalanx (LDMPPH); line 2 is the longitudinal distance central aspect of the proximal phalanx (LDCPPH); line 3 is the longitudinal distance lateral aspect of the proximal phalanx (LDLPPH); line 4 is the longitudinal distance medial aspect of the I metatarsal bone (LDM-M); line 5 is the longitudinal distance central aspect of the I metatarsal bone (LDC-M); line 6 is the longitudinal distance lateral aspect of the I metatarsal bone (LDL-M).
#
# Predicted Caption:  Anteroposterior radiograph of the knee joint showing the angle between the medial tib
# Blue score:  1.4486364479981013e-157
# --------------
# Actual Caption:  Normal image of patellar ligament in ultrasound elastography examination.
#
# Predicted Caption:  Ultrasound image of the left breast showing a hypoechoic mass with a diameter of
# Blue score:  4.829607837557235e-155
# --------------
# Actual Caption:  Computerized tomography image of the mass.
#
# Predicted Caption:  CT scan of the abdomen showing a large mass in the right kidney.
#
# Blue score:  5.019362538473707e-155
# --------------
# Actual Caption:  Axial image show huge multiloculated cystic mass with a large nephrolithiasis and thick septation.
#
# Predicted Caption:  CT scan of the abdomen showing a large cystic lesion in the right adrenal gland.
# Blue score:  5.157006819435075e-155
# --------------
# Actual Caption:  Posteroanterior chest radiograph shows dense consolidation of the lower right lung zone accompanied by pleural effusion.
#
# Predicted Caption:  Chest X-ray showing bilateral diffuse pulmonary infiltrates.
#
# Blue score:  0
# --------------
# Actual Caption:  MRI neck lateral view showing thick and short neck with restricted neck extension due to fused cervical vertebrae and the depth of the trachea from skin level to be 3.4 cm
#
# Predicted Caption:  CT scan of the cervical spine showing a large mass in the posterior aspect of the C2 verte
# Blue score:  2.5901638294976676e-155
# --------------
# Actual Caption:  Axial contrast-enhanced CT scan shows an eccentric large mass with luminal narrowing (in circle).
#
# Predicted Caption:  CT scan of the abdomen showing a large mass in the right lobe of the liver.
#
# Blue score:  6.373704167435469e-155
# --------------
# Actual Caption:  High-resolution computed tomographic image of the patient's chest showing the saddle embolus.
#
# Predicted Caption:  CT scan of the thorax showing a large mass in the right lower lobe.
#
# Blue score:  5.74340400309589e-155
# --------------
# Actual Caption:  Non-contrast computerized tomography showing multiple left basilar bullae.
#
# Predicted Caption:  CT scan of the chest showing a large mass in the right upper lobe.
#
# Blue score:  9.418382295637229e-232
# --------------
# Actual Caption:  The finding of ICG lymphography. The right upper limb is located with the palm facing upward. ICG was injected at the palmar side of the right wrist (yellow cross). Clear linear pattern is observed that is suddenly disrupted at the middle of the forearm (yellow arrow). ICG indicates indocyanine green.
#
# Predicted Caption:  The maximum intensity projection image of the left maxillary sinus (MSA) and maxillary
# Blue score:  3.2255402807783876e-156
# --------------
# Actual Caption:  Sagittal S T I R sequence showing iso to mild hyperintense signal with respect to the spinal cord.
#
# Predicted Caption:  Sagittal T2-weighted magnetic resonance imaging of the spine showing a large mass in the
# Blue score:  9.314777610904016e-232
# --------------
# Actual Caption:  Abdominal radiography showing the VPS catheter and a soft-tissue mass located in the upper abdomen.
#
# Predicted Caption:  Plain abdominal radiograph showing a large mass in the right upper quadrant of the abdomen.
#
# Blue score:  6.5900678916581e-155
# --------------
# Actual Caption:  Aedeagus with vesica everted, showing diverticula.
#
# Predicted Caption:  Axial CT scan of the left shoulder showing a large soft tissue mass in the left shoulder.
# Blue score:  8.972141065609098e-232
# --------------
# Actual Caption:  An enhanced CT Scan of the abdomen showing a splenic abscess communicating with another subcutaneous abscess through the lower chest wall
#
# Predicted Caption:  CT scan of the abdomen showing a large mass in the right lobe of the liver.
#
# Blue score:  0.18219633533937166
# --------------
# Actual Caption:  Working length radiograph
#
# Predicted Caption:  Preoperative radiograph of the patient
#
# Blue score:  1.2183324802375697e-231
# --------------
# Actual Caption:  MRI demonstrating superior sagittal sinus thrombosis
#
# Predicted Caption:  Sagittal T1-weighted image shows a large mass in the posterior aspect of the left
# Blue score:  0
# --------------
# Actual Caption:  Anteroposterior radiographic view 5 year after injury.
#
# Predicted Caption:  Radiograph of the right hip showing a fracture of the femoral head with a fracture of
# Blue score:  0
# --------------
# Actual Caption:  Patterns of enhancement on T2 weighted MRI classified as severe demonstrating right intraparenchymal hematoma (arrow) with surrounding hyperintensity. Figure is reproduced with permission (76).
#
# Predicted Caption:  Axial T2-weighted image shows a hyperintense lesion in the left par
# Blue score:  0
# --------------
# Actual Caption:  Case 1: Intraoperative final anteroposterior (AP) fluoroscopic image. The twelfth rib is the inferior-most rib.
#
# Predicted Caption:  Fluoroscopic image of the left renal pelvis.
#
# Blue score:  3.571883312829026e-232
# --------------
# Actual Caption:  Curved multiplanar TeraRecon reconstruction of axillary artery with measurement at point B in axillary artery.
#
# Predicted Caption:  CT angiography showing a large right subclavian artery (arrow) with a diameter
# Blue score:  9.065607048138757e-232
# --------------
# Actual Caption:  Fig 2Barium swallow study showing a giant type II paraesophageal hiatus hernia. More than 1/ 3 of the stomach is above the diaphragm (arrow)
#
# Predicted Caption:  Postoperative chest X-ray showing the right-sided pleural effusion.
#
# Blue score:  1.7434293862051595e-232
# --------------
# Actual Caption:  Apical four chamber view showing right ventricular thrombus (red arrow) and left ventricular thrombus (white arrow). The left ventricular thrombus is larger than the right.
#
# Predicted Caption:  Transesophageal echocardiography showing a large mass in the left atrium
# Blue score:  3.0084785153578235e-232
# --------------
# Actual Caption:  Image of good injection, right T2.
#
# Predicted Caption:  Fluoroscopic image of the left internal carotid artery.
#
# Blue score:  1.0832677820940877e-231
# --------------
# Actual Caption:  A direct postoperative radiograph is shown with a segmental defect reconstructed with a structural cortical autograft.
#
# Predicted Caption:  Radiograph of the left hip showing a fracture of the femoral head with a fracture of
# Blue score:  4.987693055201041e-155
# --------------
# Actual Caption:  Figure 3. Close up of Figure 2. The bladder is marked with an open arrowhead. The largest left diverticulum with a left sided position is marked with an open arrow.
#
# Predicted Caption:  Ultrasound image of the right breast showing a hypoechoic mass (arrow) with
# Blue score:  2.8744291130001147e-232
# --------------
# Actual Caption:  Laterolateral radiographic view of lumbosacral discospondylitis of the same heifer calf four weeks after the start of antibiotic treatment. In the periphery of the lytic zones, the margins of the adjacent endplate sclerosis are more defined (arrows).
#
# Predicted Caption:  Lateral radiograph of the left hip showing the fracture of the femoral head (arrow)
# Blue score:  1.39691691770113e-155
# --------------
# Actual Caption:  Chest X-ray showing multiple cavitary lesions of left upper lobe, with fibrosis of mediastinum causing deviation of trachea to left side and tenting of left lobe of diaphragm.
#
# Predicted Caption:  Chest X-ray showing a large right-sided pleural effusion.
#
# Blue score:  3.6648220885102645e-79
# --------------
# Actual Caption:  Renal artery aneurysm: Axial contrast-enhancedCT image showing intensely enhancing left renal artery aneurysm (arrow)
#
# Predicted Caption:  CT scan of the abdomen showing a large heterogeneous mass in the right kidney (arrow) with
# Blue score:  1.0832677820940877e-231
# --------------
# Actual Caption:  The atypical fracture of the right femur.
#
# Predicted Caption:  Postoperative radiograph of the pelvis showing the reduction of the fracture.
#
# Blue score:  5.477489369001354e-155
# --------------
# Actual Caption:  Abnormal gallbladder with thickened wall and mass in the fundus on ultrasound.
#
# Predicted Caption:  Ultrasound image of the right kidney.
#
# Blue score:  4.282289549833951e-232
# --------------
# Actual Caption:  Typical cases, anterioposterior film in pre-operation.
#
# Predicted Caption:  Plain radiograph of the thorax showing the position of the thoracic spine in relation to
# Blue score:  9.257324954728539e-232
# --------------
# Actual Caption:  Arrows indicating radiolucency around aortic arch by fluoroscopy.
#
# Predicted Caption:  Angiography of the left anterior descending artery (LAD) showing the presence of a large
# Blue score:  0
# --------------
# Actual Caption:  Thickness of the frontal beak (FB) in prasagittal CT image. The thickness of the FB was measured on the parasagittal image where the FB showed the most prominent.
#
# Predicted Caption:  Coronal CT scan of the head showing a large mass in the right maxillary sinus (
# Blue score:  2.676954841210826e-155
# --------------
# Actual Caption:  Third-degree burn on the lateral face of the left thigh.
#
# Predicted Caption:  The image of the left eye showing the presence of a large mass in the left eye.
#
# Blue score:  2.570061783884003e-78
# --------------
# Actual Caption:  X-Ray lower end of femur showing Giant Cell Tumor.
#
# Predicted Caption:  Radiograph of the right knee showing a large osteolytic lesion in the medial aspect
# Blue score:  1.1200407237786664e-231
# --------------
# Actual Caption:  Asterix and arrows showing partial vein obstructions
#
# Predicted Caption:  Fluorescein angiography of the right eye showing a large amount of fluoresce
# Blue score:  9.788429383461836e-232
# --------------
# Actual Caption:  Five years after laparoscopic cholecystectomy. A single biliary concretion (arrow) is seen in the hepatorenal recess. L – liver
#
# Predicted Caption:  Ultrasound image of the liver showing a large, heterogeneous, hypoechoic mass
# Blue score:  5.748666558742058e-232
# --------------
# Actual Caption:  The superselective catheterization of an ileal artery shows voluminous disorder with abnormal arterial structures and areas of stagnation of the contrast medium.
#
# Predicted Caption:  Angiography of the left internal carotid artery showing a large pseudoaneurysm
# Blue score:  2.2300257414666443e-155
# --------------
# Actual Caption:  Right ventricular mass. Echocardiographic image of the thrombus in the right ventricle. LV Left ventricle, RA Right atrium, RV Right ventricle
#
# Predicted Caption:  Transesophageal echocardiography showing a large mass in the left atrium
# Blue score:  1.9171017214771757e-155
# --------------
# Actual Caption:  On computed tomography, massive venous collaterals are evident around common bile duct
#
# Predicted Caption:  CT scan of the abdomen showing a large cystic mass in the right adrenal gland.
#
# Blue score:  0
# --------------
# Actual Caption:  Preliminary cavography: caval involvement (arrow) from a retroperitoneal mass (pelvic leiomyomatosis).
#
# Predicted Caption:  Abdominal X-ray showing a large bowel obstruction.
#
# Blue score:  6.325072941044999e-232
# --------------
# Actual Caption:  T1-weighted brain MRI showing hyperintensities in substantia nigra
#
# Predicted Caption:  Magnetic resonance imaging of the brain showing a large mass lesion in the left frontal lobe
#
# Blue score:  1.1988328686372911e-231
# --------------
# Actual Caption:  FSE, T2WI, coronal plane. Callosal injury as a result of multiple shunting procedures.
#
# Predicted Caption:  Magnetic resonance imaging of the brain showing a large mass in the left parietal lobe.
#
# Blue score:  1.1008876702055895e-231
# --------------
# Actual Caption:  IVP showing resolved bilateral hydronephrosis 2 months after starting corticosteroid therapy
#
# Predicted Caption:  Plain abdominal radiograph showing a large mass in the right upper quadrant of the abdomen.
#
# Blue score:  9.257324954728539e-232
# --------------
# Actual Caption:  Anteroposterior fluoroscopic image of contrast injected through the second epidural catheter which was placed on the left side of the epidural space showing spread only to the left-sided nerve roots.
#
# Predicted Caption:  Fluoroscopic image of the left internal jugular vein.
#
# Blue score:  6.487997819313444e-156
# --------------
# Actual Caption:  Inconclusive for ependymal enhancement on magnetic resonance imaging. Axial gadolinium-enhanced T1-weighted image showing a ring enhancing lesion on the left side compressing the left lateral ventricle making it impossible to appreciate ependymal enhancement
#
# Predicted Caption:  Axial T1-weighted image of the brain showing a large mass lesion in the
# Blue score:  1.8124903584036124e-155
# --------------
# Actual Caption:   18F-FDG-PET scan shows two focal FDG-avid uptakes in the right axilla (SUV max 12.7, black arrow) and right adrenal gland (SUV max 4.7, white arrow). SUV max: maximum standardized uptake value. 18F-FDG-PET: 18F-fluorodeoxyglucose-positron emission tomography.
#
# Predicted Caption:  A representative image of a patient with a history of a history of a history of a history of
# Blue score:  0
# --------------
# Actual Caption:  Lateral radiograph showing unreported right ventricular implantable cardioverter-defibrillator lead perforations.
#
# Predicted Caption:  Postoperative lateral cephalometric radiograph of the patient.
#
# Blue score:  7.296382734947757e-232
# --------------
# Actual Caption:  Coronal maximum intensity projection of the aorta (Ao) demonstrating a paravalvular mycotic pseudoaneurysm arising from the aortic root (arrow).
#
# Predicted Caption:  Coronal CT image of the thorax shows a large mass (arrow) in the right at
# Blue score:  4.487950221566228e-155
# --------------
# Actual Caption:  Consolidation in the right lower lobe due to aspiration in an 85-year-old patient (aspiration was confirmed using fluoroscopy).
#
# Predicted Caption:  Chest X-ray showing a large right-sided pleural effusion.
#
# Blue score:  0
# --------------
# Actual Caption:  Complication of iris perforation by IOL loop
#
# Predicted Caption:  The image shows the position of the needle in the anterior segment of the left eye. The needle
# Blue score:  8.844844403089352e-232
# --------------
# Actual Caption:  Flouroscopic image of the stent after insertion
#
# Predicted Caption:  Fluoroscopic image of the left ureteral diverticulum.
#
# Blue score:  5.021333847570327e-78
# --------------
# Actual Caption:  A representative image of the magnetic resonance image of fluid-attenuated inversion recovery with spectroscopy shows significant interval increase in the size of periventricular masses in the bilateral caudates with associated restricted diffusion
#
# Predicted Caption:  Axial T2-weighted image shows a hyperintense lesion in the left frontal
# Blue score:  9.654535748551578e-156
# --------------
# Actual Caption:  Step-ladder artifacts (arrows) caused by numerous PVC
#
# Predicted Caption:  Coronal T2-weighted image shows a large cystic lesion (arrow) in
# Blue score:  0
# --------------
# Actual Caption:  X-ray transmission image.
#
# Predicted Caption:  Lateral radiograph of the left knee showing the osteolytic lesion in the medial aspect
# Blue score:  0
# --------------
# Actual Caption:  Abdominal computed-tomography scan showing bilaterally enlarged kidneys.
#
# Predicted Caption:  CT scan of the abdomen and pelvis showing the presence of a large mass in the right
# Blue score:  1.0669733992029681e-231
# --------------
# Actual Caption:  Chest PA view.
#
# Predicted Caption:  Chest X-ray showing a large right-sided pleural effusion.
#
# Blue score:  1.0832677820940877e-231
# --------------
# Actual Caption:  T1 image axial view postcontrast film.
#
# Predicted Caption:  Axial T1-weighted image of the brain showing a hyperintense lesion in
# Blue score:  1.0003688322288243e-231
# --------------
# Actual Caption:  Aplasia of clavicles, bell shaped thorax
#
# Predicted Caption:  Chest X-ray showing a large right-sided pleural effusion
#
# Blue score:  0
# --------------
# Actual Caption:  One month after PMCT only, the necrosis area surrounded the tumor area completely (CT CE).Abbreviation: PMCT, percutaneous microwave coagulation therapy.
#
# Predicted Caption:  CT scan of the abdomen showing a large mass in the right lobe of the liver.
#
# Blue score:  8.436497969708995e-232
# --------------
# Actual Caption:  Magnetic resonance imaging of a 6.7 cm×3.0 cm×8.3 cm enhanced irregular mass with an intermediate signal intensity on the T2 weighted image and good development of the vascular structure accompanied by diffuse subcutaneous edema.
#
# Predicted Caption:  Magnetic resonance imaging of the pelvis showing a large mass in the right iliopsoas
# Blue score:  0.054445623455268766
# --------------
# Actual Caption:  Coronal reformatted CT image depicts dilated pancreatic duct (arrowhead) due to obstructing tumor (arrow) in the pancreatic head.
#
# Predicted Caption:  Coronal CT image of the abdomen and pelvis showing a large heterogeneous mass (arrow)
# Blue score:  4.563654228805124e-155
# --------------
# Actual Caption:  An example DXA image. This is a DXA image taken from the MrOS cohort. The 58 points used for the SSM are marked on the image. Key points are marked in red and these represent anatomical reference points to ensure accurate marking. There are two key lateral acetabular points placed on the outer edge of the acetabulum and one key medial acetabular point placed at the end of the acetabular eyebrow. The other key points are located around the trochanters, the femoral head and the femoral neck.
#
# Predicted Caption:  Anteroposterior radiograph of the right knee showing the position of the femoral head
# Blue score:  1.4718327923215803e-80
# --------------
# Actual Caption:  Non contrast CT axial section (pulmonary window) shows the endobronchial mass (red arrow) that obstructs the right main bronchus.
#
# Predicted Caption:  CT scan of the chest showing a large mass in the right upper lobe.
#
# Blue score:  4.249048591879317e-155
# --------------
# Actual Caption:  Sagittal view of CT scan of the abdomen showing ascending colon thickening (arrow).
#
# Predicted Caption:  CT scan of the abdomen and pelvis showing a large mass in the right iliac foss
# Blue score:  0.23961829057131984
# --------------
# Actual Caption:  The PLSVC draining into the left superior pulmonary vein then into the left atrium.
#
# Predicted Caption:  Coronary angiography showing a large left anterior descending artery (LAD) originating from
# Blue score:  8.285726588482745e-232
# --------------
# Actual Caption:  Correlative endoscopic ultrasound image revealing the muscularis propria (white arrows), serosa (black arrows), and an area in which the mass invades these layers (red oval). The mucosal and submucosal layers are obliterated by the mass and difficult to identify in this image.
#
# Predicted Caption:  Ultrasound image of the left testis. The arrow indicates the testis.
#
# Blue score:  8.448008408714654e-233
# --------------
# Actual Caption:  Right pleural effusion with associated basilar atelctasis.
#
# Predicted Caption:  Chest X-ray showing a large right-sided pleural effusion.
#
# Blue score:  1.0832677820940877e-231
# --------------
# Actual Caption:  Hydatid cyst at the hepatic hilum, the cavernous transformation of the portal vein and patent superior mesenteric vein
#
# Predicted Caption:  CT scan of the abdomen and pelvis showing a large mass in the right iliac foss
# Blue score:  4.729852449410561e-155
# --------------
# Actual Caption:  Intraoperative T-tube cholangiogram.
#
# Predicted Caption:  Coronal view of the left kidney showing a large cystic lesion in the left renal pel
# Blue score:  0
# --------------
# Actual Caption:  Echocardiography showing a massive hemorrhagic pericardial effusion (arrow).
#
# Predicted Caption:  Transesophageal echocardiography showing a large mass (arrow) in the
# Blue score:  6.08970970641905e-155
# --------------
# Actual Caption:  CBCT image showing the palatal location of the impacted secondary canine
#
# Predicted Caption:  Axial CT scan of the neck showing the fracture of the right maxillary sinus.
#
# Blue score:  6.830096904817037e-155
# --------------
# Actual Caption:  Enlarged supraclavicular node.
#
# Predicted Caption:  CT scan of the abdomen showing a large mass in the right parotid gland.
#
# Blue score:  0
# --------------
# Actual Caption:  Nasal cavity width. Measured in millimeters from the anterior nasal spine to the lateral wall of the nasal base on the side of the impacted canine and canine without impaction
#
# Predicted Caption:  Panoramic radiograph of the patient.
#
# Blue score:  5.6519694558963347e-157
# --------------
# ...
#
# Predicted Caption:  Angiography of the left internal carotid artery showing a large left internal carotid
# Blue score:  2.971081082719087e-79
# --------------
# Actual Caption:  EUS showing a 4.9 × 4.1-cm solid pancreatic body mass with anechoic complex structures.
#
# Predicted Caption:  Ultrasound image of the left ovary.
#
# Blue score:  0
# --------------
# Actual Caption:  CT scan showing non-enhancing large left suprarenal mass
#
# Predicted Caption:  CT scan showing a large cystic lesion in the right adrenal gland.
#
# Blue score:  3.4077295621678842e-78
# --------------
# Actual Caption:  Magnetic resonance of abdomen. Coronal view.
#
# Predicted Caption:  Magnetic resonance imaging of the abdomen and pelvis showing a large mass in the right adrenal gland
# Blue score:  4.83404070852666e-155
# --------------
# Actual Caption:  Pretreatment CT scan.
#
# Predicted Caption:  CT scan of the chest showing a large mass in the right upper lobe.
#
# Blue score:  9.418382295637229e-232
# --------------
# Actual Caption:  Is an apical four chamber view 2 weeks post pericardiocentesis and development of LV dysfunction showing resolution of the apical ballooning in systole with normal LV systolic function
#
# Predicted Caption:  Transesophageal echocardiography showing a large mass in the left atrium
# Blue score:  2.2287357007065595e-232
# --------------
# Actual Caption:  MR Coronal T1 WI showing heterogeneous enhancing sellar/suprasellar mass with supratentorial obstructive hydrocephalus.
#
# Predicted Caption:  Coronal T1-weighted MRI image showing a large mass in the left parotid
# Blue score:  1.1852285898528657e-231
# --------------
# Actual Caption:  Sagittal CT section showing the lesion extending superiorly from nasopharynx inferiorly up to hyoid bone
#
# Predicted Caption:  Computed tomography scan of the neck showing a large mass in the left parotid gland
# Blue score:  1.1008876702055895e-231
# --------------
# Actual Caption:  US of the wrist: synovial hypertrophy with poorly enhanced synovial vascularity in the distal radioulnar joint (synovitis)
#
# Predicted Caption:  Ultrasound image of the left knee. The arrow indicates the medial aspect of the knee.
# Blue score:  4.513274774492109e-155
# --------------
# Actual Caption:  M-mode tracing demonstrating excellent contractility. RV: right ventricle, LV: left ventricle.
#
# Predicted Caption:  Transesophageal echocardiography showing a large mass in the left atrium
# Blue score:  9.269981669466712e-232
# --------------
# Actual Caption:  Post-operative contrast study. Radiographic image showing patency and position of the stents, with contrast flow into the duodenum (arrow). The image demonstrates successful resolution of outlet obstruction.
#
# Predicted Caption:  Aortogram showing a large aneurysm of the right common iliac artery (
# Blue score:  1.65936125050445e-155
# --------------
# Actual Caption:  Normalization of the systolic compression at the mid-portion of LAD
#
# Predicted Caption:  Angiography of the left anterior descending artery (LAD) showing a large left anterior descending
# Blue score:  4.829607837557235e-155
# --------------
# Actual Caption:  MRI brain showing hypoplastic pituitary with visible stalk and absent splenium of corpus callosum
#
# Predicted Caption:  Magnetic resonance imaging of the brain showing a large mass lesion in the left frontal lobe.
#
# Blue score:  4.987693055201041e-155
# --------------
# Actual Caption:  Enhanced CT on admission. Enhanced CT shows a deep liver laceration (Grade IV on the Organ Injury Scale of the American Association for Surgery of Trauma) without extravasation or pseudoaneurysm or arterioportal fistula formation.
#
# Predicted Caption:  CT scan of the abdomen showing a large mass in the right lobe of the liver.
#
# Blue score:  1.925643667191205e-155
# --------------
# Actual Caption:  X-ray one month after the implant, with no displacement of seeds using Pro-Link system™ and real-time procedure
#
# Predicted Caption:  The image of the left eye in a patient with a history of eye cancer. The image shows
# Blue score:  1.1640469867513693e-231
# --------------
# Actual Caption:  X-ray of the left shoulder showing hypertrophic dislocated shoulder joint
#
# Predicted Caption:  Radiograph of the right hip showing a fracture of the femoral head with a fracture of
# Blue score:  4.987693055201041e-155
# --------------
# Actual Caption:  Chest X ray (CXR) showed increased perihilar infiltrates indicating acute pulmonary edema (APE).
#
# Predicted Caption:  Chest X-ray showing a large right-sided pleural effusion.
#
# Blue score:  5.798314605122797e-232
# --------------
# Actual Caption:  Axial T2W image shows an enlarged right external iliac lymph node (arrow)
#
# Predicted Caption:  Magnetic resonance imaging of the pelvis showing a large mass in the right iliopsoas
# Blue score:  9.418382295637229e-232
# --------------
# Actual Caption:  Desquamative interstitial pneumonia (DIP). HRCT at the level of the lower lobes demonstrates a “reticular pattern” consisted of subpleural traction bronchiolectasis and bronchiectasis, thickening of the peribronchovascular interstitium, ground-glass opacity and minimal honeycombing. Bilateral pleural effusions—which are not a finding of DIP—are attributed to cardiac failure
#
# Predicted Caption:  CT scan of the chest showing a large cystic lesion in the right upper lobe.
#
# Blue score:  7.01601422006543e-156
# --------------
# Actual Caption:  View of popcorn calcification in a patient with hamartoma
#
# Predicted Caption:  Chest radiograph showing a large right-sided pleural effusion (arrow)
#
# Blue score:  1.0518351895246305e-231
# --------------
# Actual Caption:  In September 2016, MR scan showed brain occupancy
#
# Predicted Caption:  Magnetic resonance imaging of the brain showing a large mass lesion in the left frontal lobe.
#
# Blue score:  9.109159947227211e-232
# --------------
# Actual Caption:  Working length determination X-ray
#
# Predicted Caption:  Postoperative radiograph
#
# Blue score:  0
# --------------
# Actual Caption:  Chest X-ray showing a community-acquired pneumonia due to A. pittii with a large pulmonary cavity of the right lower lobe, at hospital admission
#
# Predicted Caption:  Chest X-ray showing bilateral diffuse pulmonary infiltrates.
#
# Blue score:  5.487577660135799e-79
# --------------
# Actual Caption:  Endoscopic retrograde cholangiopancreatography (ERCP) image (hospital day 14) showing no apparent abnormality in the intrahepatic or common bile ducts.
#
# Predicted Caption:  Aortography showing a large aneurysm of the right common carotid artery.
# Blue score:  6.361945342945876e-232
# --------------
# Actual Caption:  Thrombosis of perforan vein.
#
# Predicted Caption:  Ultrasound image of the left breast showing a hypoechoic mass with a diameter of
# Blue score:  9.418382295637229e-232
# --------------
# Actual Caption:  TDM du massif facial montrant un comblement du sinus maxillaire droit avec des polypes nasosinusiens
#
# Predicted Caption:  Axial CT scan of the head showing the presence of a large mass in the right maxillary
# Blue score:  0
# --------------
# Actual Caption:  Optical coherence tomography images of the cornea 1 month after accelerated cross-linking.
#
# Predicted Caption:  The image of the left eye in the cornea. The image shows the position of the ret
# Blue score:  4.368048869756373e-155
# --------------
# Actual Caption:  Left upper pulmonary vein to left atrium (hand injection)
#
# Predicted Caption:  Fluoroscopic image of the left ventricle.
#
# Blue score:  7.060301868108111e-232
# --------------
# Actual Caption:  CT showing inoperable ovarian cancer in the left supracolic compartment involving the spleen and stomach.
#
# Predicted Caption:  CT scan of the abdomen showing a large cystic lesion in the right adrenal gland.
# Blue score:  5.859491021246916e-155
# --------------
# Actual Caption:  Anteroposterior radiograph of the chest showing ectopic calcifications that limit thoracic inspiration.
#
# Predicted Caption:  Chest radiograph showing bilateral diffuse bilateral diffuse pulmonary infiltrates.
#
# Blue score:  8.962731118674859e-232
# --------------
# Actual Caption:  The subarachnoid space at the gyral summit demonstrates abrupt closure secondary to a mass effect within the meninges. Further, the gyral summit can be observed to flatten somewhat by the effect of meningeal mass. This is a presumed meningioma and most likely benign. The patient has been referred for MRI and further consultation. MRI is not presently available.
#
# Predicted Caption:  Ultrasound image of the left breast showing a hypoechoic mass (arrow) in
# Blue score:  2.9952459934854115e-233
# --------------
# Actual Caption:  IOUS. Chronic pancreatitis. Tortuous, expanded pancreatic duct with calcification present. Preparing for the Puestow procedure, creating an incision along the pancreatic duct, draining, and attaching the duct to a loop of the small intestine (Roux-en-Y anastomosis)
#
# Predicted Caption:  Ultrasound image of the right breast showing a hypoechoic mass (arrow) with
# Blue score:  8.422766612341776e-156
# --------------
# Actual Caption:  Axial computed tomograpic (Soft tissue window) view demonstrating extradural air collection in upper dorsal spine.
#
# Predicted Caption:  CT scan of the chest showing a large mass in the right upper lobe.
#
# Blue score:  1.0428282296630707e-231
# --------------
# Actual Caption:  C, CECT of the thorax shows pleural effusion (blue arrow), pericardial effusion (red arrow), left intercostal muscle involvement and subcutaneous nodules (green arrows).
#
# Predicted Caption:  CT scan of the chest showing a large mass in the right upper lobe.
#
# Blue score:  2.5393499636604805e-155
# --------------
# Actual Caption:  Measurement of diaphragm mobility obtained by the software. Digital radiography of the chest in anteroposterior view (AP) during maximal expiration and maximal inspiration conducted on the same film. Measurements of the mobility of right and left hemidiaphragms were obtained by the software of the device using the ruler on the image for calibration. Source: author's own production
#
# Predicted Caption:  Plain radiograph of the thoracic spine showing the position of the vertebral body in the
# Blue score:  4.6091925538702223e-156
# --------------
# Actual Caption:  Preoperative echocardiography showed two abnormal transverse shunts in pulmonary trunk. One was 1.6 mm wide (upper arrow) and the other was 0.6 mm wide (lower arrow) which were both considered as coronary to pulmonary artery shunts
#
# Predicted Caption:  Transesophageal echocardiography showing a large mass in the left atrium
# Blue score:  1.0014355036895482e-232
# --------------
# Actual Caption:  Treatment fields and the gross tumor volume for the patient in Figure 1. Treatment was with two oblique portals
#
# Predicted Caption:  CT scan of the head showing a large mass in the right parietal lobe with a central nec
# Blue score:  1.1832532987548623e-231
# --------------
# Actual Caption:  Chest scanner of November 2007 showing micronodular pulmonary lesions.
#
# Predicted Caption:  CT scan of the chest showing a large mass in the right upper lobe.
#
# Blue score:  1.1200407237786664e-231
# --------------
# Actual Caption:  Sagittal T2-weighted MRI sequence of the FHM1 case. The MRI sequence reveals a cerebellar atrophy most pronounced in the vermis.
#
# Predicted Caption:  Sagittal T2-weighted image of the brain showing a large mass in the posterior aspect
# Blue score:  5.663474975181765e-155
# --------------
# Actual Caption:  Midesophageal Long Axis (LAX) View of the Ascending Aorta With Color Doppler Demonstrating the Distances
#
# Predicted Caption:  Transesophageal echocardiography showing a large mass in the left atrium
# Blue score:  6.213854539426459e-232
# --------------
# Actual Caption:  CT abdomen/pelvis done at time of admission to outside hospital showing colonic thickening at the splenic flexure.
#
# Predicted Caption:  CT scan of the abdomen showing a large mass in the right adrenal gland.
#
# Blue score:  1.0750488753811686e-231
# --------------
# Actual Caption:  Blood flow (visible as streaks) directs heart development in zebrafish.Köster/Macmillan
#
# Predicted Caption:  Sagittal T1-weighted image of the cervical spine shows a large mass in the posterior
# Blue score:  9.418382295637229e-232
# --------------
# Actual Caption:  Axial contrast-enhanced computed tomography scan showing a well-defined heterogeneously enhanced gastric mass with coarse and diffuse calcifications.
#
# Predicted Caption:  CT scan of the abdomen and pelvis showing a large mass in the right iliac foss
# Blue score:  5.323760397095685e-155
# --------------
# Actual Caption:  right hepatic artery after embolization.
#
# Predicted Caption:  Fluoroscopic image of the left hepatic artery.
#
# Blue score:  1.1200407237786664e-231
# --------------
# Actual Caption:  Same case as in figures 1, 2 and 3. Bilateral standing long-leg orthoradiographs demonstrate a shortening of the left femoral neck due to premature closure of the physis and slip of the epiphysis on the left side. A bilateral valgus deformity of the tibia was treated with temporary hemiepiphyseodesis.
#
# Predicted Caption:  Anteroposterior radiograph of the pelvis showing a large osteolytic lesion
# Blue score:  1.290159553389831e-156
# --------------
# Actual Caption:  Master die.
#
# Predicted Caption:  The image of the left ventricle in the sagittal plane.
#
# Blue score:  0
# --------------
# Actual Caption:  Additional CT findings of schistosomiasis. The gallbladder demonstrates chronic wall thickening and nodularity (arrow), present since two years prior to this study. There is stranding surrounding the gallbladder (arrowheads). There are no stones or sludge, pericholecystic fluid, or dilatation of the biliary structures. [Powerpoint Slide]
#
# Predicted Caption:  CT scan of the abdomen showing a large mass in the right kidney (arrow).
#
# Blue score:  6.273606854590475e-156
# --------------
# Actual Caption:  CT scan detected an abscess with dimensions of 4.9 × 9.0 cm located along the subdiaphragmatic border near the gastroesophageal junction. CT identified no gastric leak. The abscess was drained with a 7-French drainage tube (arrow).
#
# Predicted Caption:  CT scan of the abdomen showing a large mass in the right lobe of the liver.
#
# Blue score:  1.69937457177788e-155
# --------------
# Actual Caption:  Measurement of the incisive canal length (green line) and anterior maxillary bone thickness at 3 levels (yellow, orange & pink lines).
#
# Predicted Caption:  Sagittal view of the maxillary sinus.
#
# Blue score:  6.885508376253759e-156
# --------------
# Actual Caption:  Grayscale ultrasound sagittal image of liver in a 37-year-old patient demonstrates a 3.2 cm hypoechoic mass in segment 6.
#
# Predicted Caption:  Ultrasound image of the right kidney.
#
# Blue score:  8.683164396086396e-156
# --------------
# Actual Caption:  Axial tomography image showing a lateral compression type injury.
#
# Predicted Caption:  CT scan of the pelvis showing the presence of a large mass in the right iliac
# Blue score:  1.0832677820940877e-231
# --------------
# Actual Caption:   Eight days after the first embolization, pelvic angiography shows collateral arteries feeding the uterus from the right external iliac artery.
#
# Predicted Caption:  Angiography of the left kidney showing a large mass in the left renal vein.
#
# Blue score:  7.296382734947757e-232
# --------------
# Actual Caption:  Presentation M reveals the enlargement of the right ventricle (RV) and an abnormal motion of the ventricular septum (↑↑) – a phenomenon that indicated the possibility of a low-pressure systemic-pulmonary shunt despite the absence of the atrial septal defect. Additional marking: LV – left ventricle
#
# Predicted Caption:  Transesophageal echocardiography (TEE) image of the left vent
# Blue score:  7.035476938866056e-157
# --------------
# Average BLEU score: 0.0056659454747024

# %% [markdown]
# # Computing BLEU and ROUGE score

# %%
import evaluate


bleu = evaluate.load("bleu")
rouge = evaluate.load("rouge")


def calculate_bleu_and_rouge(reference: str, hypothesis: str):
    """
    Inputs: Reference -> Target caption, Hypothesis -> Generated caption
    Outputs: Dictionary of bleu score and rouge score
    Description: This function computes the bleu score as well as rouge1, rouge2, rougeL, and rougeLsum
    """
    
    bleu_score = bleu.compute(predictions=[hypothesis], references=[reference])
    rouge_score = rouge.compute(
        predictions=[hypothesis], references=[reference]
    )

    return {"bleu_score": bleu_score, "rouge_score": rouge_score}

# %% [raw]
# # Use the below code for reference
#
# for _, row in test_input.iterrows():
#     input_id = row["id"]
#     input_text = row["semtypes"]
#
#     # Tokenize the input text
#     input_ids = tokenizer.encode(input_text, return_tensors="pt")
#     input_ids = input_ids.to(device)
#
#     # Generate captions using the model
#     outputs = model.generate(input_ids)
#
#     # Decode the generated captions
#     generated_captions = tokenizer.decode(outputs[0], skip_special_tokens=True)
#
#     target_caption = test_target[test_target["id"] == input_id]["caption"].values[0]
#
#     # Calculating BLEU score and ROGUE score between the captions
#
#     score = calculate_bleu_and_rouge(target_caption, generated_captions)
#     bleu_score, rouge_score = score["bleu_score"], score["rouge_score"]
#
#     temp = {
#         "id": input_id,
#         "input_text": input_text,
#         "generated_caption": generated_captions,
#         "target_caption": target_caption,
#         "bleu_score": bleu_score,
#         "rouge_score": rouge_score,
#     }
#
#     res.append(temp)
