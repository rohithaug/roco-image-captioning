# %%
# params
test_valid_percentage = 30 # (test - 15, valid - 15)

train_data_percentage = 100
valid_data_percentage = 100
test_data_percentage = 100

max_target_length = 256

random_state = 77

# %%
import os
import re
import json
import torch
import numpy as np
import pandas as pd
from PIL import Image

# %%
from transformers import VisionEncoderDecoderModel, AutoFeatureExtractor,AutoTokenizer
os.environ["WANDB_DISABLED"] = "true"

# %%
import nltk
try:
    nltk.data.find("tokenizers/punkt")
except (LookupError, OSError):
    nltk.download("punkt", quiet=True)

# %% [markdown]
# ## Initialize VisionEncoderDecoderModel

# %%
from transformers import VisionEncoderDecoderModel, AutoTokenizer, AutoFeatureExtractor

image_encoder_model = "google/vit-base-patch16-224-in21k"
text_decode_model = "gpt2"

model = VisionEncoderDecoderModel.from_encoder_decoder_pretrained(image_encoder_model, text_decode_model)
# Out:
# Some weights of GPT2LMHeadModel were not initialized from the model checkpoint at gpt2 and are newly initialized: ['h.9.crossattention.c_proj.weight', 'h.8.crossattention.bias', 'h.3.crossattention.c_proj.weight', 'h.2.crossattention.c_attn.weight', 'h.8.crossattention.c_attn.weight', 'h.8.ln_cross_attn.weight', 'h.6.crossattention.c_proj.weight', 'h.3.crossattention.masked_bias', 'h.1.crossattention.c_attn.weight', 'h.2.crossattention.q_attn.weight', 'h.0.crossattention.c_attn.weight', 'h.9.crossattention.c_attn.weight', 'h.7.crossattention.c_proj.bias', 'h.7.crossattention.bias', 'h.4.crossattention.bias', 'h.9.crossattention.c_proj.bias', 'h.1.crossattention.masked_bias', 'h.6.crossattention.bias', 'h.5.crossattention.bias', 'h.6.crossattention.masked_bias', 'h.3.crossattention.bias', 'h.1.crossattention.c_proj.weight', 'h.8.crossattention.c_proj.weight', 'h.7.crossattention.c_attn.weight', 'h.10.crossattention.masked_bias', 'h.11.crossattention.q_attn.weight', 'h.10.crossattention.c_proj.bias', 'h.8.crossattention.masked_bias', 'h.0.crossattention.q_attn.weight', 'h.10.crossattention.c_attn.weight', 'h.0.crossattention.c_proj.weight', 'h.5.crossattention.masked_bias', 'h.9.ln_cross_attn.weight', 'h.7.crossattention.q_attn.weight', 'h.4.crossattention.c_proj.weight', 'h.2.crossattention.masked_bias', 'h.10.ln_cross_attn.weight', 'h.1.ln_cross_attn.weight', 'h.1.crossattention.c_proj.bias', 'h.3.ln_cross_attn.weight', 'h.10.crossattention.q_attn.weight', 'h.2.crossattention.bias', 'h.3.crossattention.q_attn.weight', 'h.2.ln_cross_attn.weight', 'h.4.crossattention.masked_bias', 'h.0.crossattention.c_proj.bias', 'h.1.crossattention.bias', 'h.8.crossattention.c_proj.bias', 'h.6.crossattention.c_proj.bias', 'h.10.crossattention.bias', 'h.11.crossattention.c_proj.weight', 'h.7.crossattention.c_proj.weight', 'h.0.crossattention.masked_bias', 'h.7.ln_cross_attn.weight', 'h.11.crossattention.bias', 'h.5.crossattention.q_attn.weight', 'h.0.crossattention.bias', 'h.9.crossattention.masked_bias', 'h.11.crossattention.c_attn.weight', 'h.6.ln_cross_attn.weight', 'h.11.crossattention.masked_bias', 'h.7.crossattention.masked_bias', 'h.9.crossattention.q_attn.weight', 'h.8.crossattention.q_attn.weight', 'h.4.crossattention.c_attn.weight', 'h.4.crossattention.q_attn.weight', 'h.2.crossattention.c_proj.bias', 'h.1.crossattention.q_attn.weight', 'h.4.crossattention.c_proj.bias', 'h.5.crossattention.c_proj.bias', 'h.3.crossattention.c_attn.weight', 'h.11.ln_cross_attn.weight', 'h.10.crossattention.c_proj.weight', 'h.4.ln_cross_attn.weight', 'h.5.crossattention.c_proj.weight', 'h.5.ln_cross_attn.weight', 'h.0.ln_cross_attn.weight', 'h.3.crossattention.c_proj.bias', 'h.11.crossattention.c_proj.bias', 'h.5.crossattention.c_attn.weight', 'h.6.crossattention.q_attn.weight', 'h.9.crossattention.bias', 'h.2.crossattention.c_proj.weight', 'h.6.crossattention.c_attn.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# image feature extractor
feature_extractor = AutoFeatureExtractor.from_pretrained(image_encoder_model)
# text tokenizer
tokenizer = AutoTokenizer.from_pretrained(text_decode_model)

# %%
# GPT2 only has bos/eos tokens but not decoder_start/pad tokens
tokenizer.pad_token = tokenizer.eos_token

# update the model config
model.config.eos_token_id = tokenizer.eos_token_id
model.config.decoder_start_token_id = tokenizer.bos_token_id
model.config.pad_token_id = tokenizer.pad_token_id

# %%
output_dir = "vit-gpt-model"
model.save_pretrained(output_dir)
feature_extractor.save_pretrained(output_dir)
tokenizer.save_pretrained(output_dir)
# Out:
# ('vit-gpt-model\\tokenizer_config.json',
#  'vit-gpt-model\\special_tokens_map.json',
#  'vit-gpt-model\\vocab.json',
#  'vit-gpt-model\\merges.txt',
#  'vit-gpt-model\\added_tokens.json',
#  'vit-gpt-model\\tokenizer.json')

# %% [markdown]
# ## Data Loading and Preparation

# %%
# file paths data
image_dir = './all_data/train/radiology/images/'
data_file = './all_data/train/radiology/traindata.csv'

# %%
data = pd.read_csv(data_file)
data
# Out:
#                id                                           name  \
# 0      ROCO_00002                 PMC4083729_AMHSR-4-14-g002.jpg
# 1      ROCO_00003              PMC2837471_IJD2009-150251.001.jpg
# 2      ROCO_00004         PMC2505281_11999_2007_30_Fig6_HTML.jpg
# 3      ROCO_00005              PMC3745845_IJD2013-683423.005.jpg
# 4      ROCO_00007          PMC4917066_amjcaserep-17-301-g001.jpg
# ...           ...                                            ...
# 65445  ROCO_81819  PMC3517833_CRIM.HEMATOLOGY2012-490438.001.jpg
# 65446  ROCO_81820               PMC5487234_rb-50-03-0190-g13.jpg
# 65447  ROCO_81821                 PMC2974222_kjr-11-612-g001.jpg
# 65448  ROCO_81822                 PMC3532764_AJNS-7-151-g002.jpg
# 65449  ROCO_81823               PMC3509000_pone.0050319.g002.jpg
#
#                                                  caption
# 0       Computed tomography scan in axial view showin...
# 1       Bacterial contamination occurred after comple...
# 2       The patient had residual paralysis of the han...
# 3        Panoramic radiograph after immediate loading.\n
# 4       Plain abdomen x-ray: Multiple air levels at t...
# ...                                                  ...
# 65445   Initial CT abdomen with contrast showing a di...
# 65446   44-year-old male patient after surgical amput...
# 65447   Primary pulmonary tuberculosis in 18-year-old...
# 65448   MRI brain with gadolinium, coronal view, show...
# 65449   Contrast-enhanced 3D MRL image of the lower e...
#
# [65450 rows x 3 columns]

# %%
# Replace column name 'name' with 'image_path'
data['image_path'] = data.pop('name')

# Prepend 'image_dir' to all entries in 'image_path' column
data['image_path'] = image_dir + data['image_path']

data
# Out:
#                id                                            caption  \
# 0      ROCO_00002   Computed tomography scan in axial view showin...
# 1      ROCO_00003   Bacterial contamination occurred after comple...
# 2      ROCO_00004   The patient had residual paralysis of the han...
# 3      ROCO_00005    Panoramic radiograph after immediate loading.\n
# 4      ROCO_00007   Plain abdomen x-ray: Multiple air levels at t...
# ...           ...                                                ...
# 65445  ROCO_81819   Initial CT abdomen with contrast showing a di...
# 65446  ROCO_81820   44-year-old male patient after surgical amput...
# 65447  ROCO_81821   Primary pulmonary tuberculosis in 18-year-old...
# 65448  ROCO_81822   MRI brain with gadolinium, coronal view, show...
# 65449  ROCO_81823   Contrast-enhanced 3D MRL image of the lower e...
#
#                                               image_path
# 0      ./all_data/train/radiology/images/PMC4083729_A...
# 1      ./all_data/train/radiology/images/PMC2837471_I...
# 2      ./all_data/train/radiology/images/PMC2505281_1...
# 3      ./all_data/train/radiology/images/PMC3745845_I...
# 4      ./all_data/train/radiology/images/PMC4917066_a...
# ...                                                  ...
# 65445  ./all_data/train/radiology/images/PMC3517833_C...
# 65446  ./all_data/train/radiology/images/PMC5487234_r...
# 65447  ./all_data/train/radiology/images/PMC2974222_k...
# 65448  ./all_data/train/radiology/images/PMC3532764_A...
# 65449  ./all_data/train/radiology/images/PMC3509000_p...
#
# [65450 rows x 3 columns]

# %%
# for index, row in data.iterrows():
#     image_path = row['image_path']
#     if not os.path.exists(image_path):
#         data.drop(index, inplace=True)
#     else:
#         try:
#             image = Image.open(image_path)
#         except Exception:
#             data.drop(index, inplace=True)
        
# # Reset the index after dropping rows
# data.reset_index(drop=True, inplace=True)

# data

# %%
# LLM output
f = open('./all_data/llm_result.txt', "r")
contents = f.read()
contents = contents.replace("\n", "")
json_data = json.loads(contents)

llm_df = pd.DataFrame(json_data)

llm_df = llm_df.drop('index', axis=1)

llm_df = llm_df[llm_df['relationship'].apply(lambda x: re.search(r'\w', str(x)) is not None)]
llm_df = llm_df.reset_index(drop=True)

llm_df

# %%
# Filter ones that have been training by the LLM
data = data.merge(llm_df, on='id')
data
# Out:
#              id                                            caption  \
# 0    ROCO_00002   Computed tomography scan in axial view showin...
# 1    ROCO_00003   Bacterial contamination occurred after comple...
# 2    ROCO_00004   The patient had residual paralysis of the han...
# 3    ROCO_00007   Plain abdomen x-ray: Multiple air levels at t...
# 4    ROCO_00008   A 3-year-old child with visual difficulties. ...
# ..          ...                                                ...
# 500  ROCO_00651   Fig. 5Fluorescein angiography: early hyperflu...
# 501  ROCO_00652   Transverse CT thorax image at the level of th...
# 502  ROCO_00653   Computed tomography revealing right upper-lun...
# 503  ROCO_00654   Lateral fluoroscopic view in a 77-year-old os...
# 504  ROCO_00655   Retrograde ureterogram reveals complete urete...
#
#                                             image_path  \
# 0    ./all_data/train/radiology/images/PMC4083729_A...
# 1    ./all_data/train/radiology/images/PMC2837471_I...
# 2    ./all_data/train/radiology/images/PMC2505281_1...
# 3    ./all_data/train/radiology/images/PMC4917066_a...
# 4    ./all_data/train/radiology/images/PMC4805615_1...
# ..                                                 ...
# 500  ./all_data/train/radiology/images/PMC5052491_J...
# 501  ./all_data/train/radiology/images/PMC4751134_j...
# 502  ./all_data/train/radiology/images/PMC5585904_1...
# 503  ./all_data/train/radiology/images/PMC3119972_A...
# 504  ./all_data/train/radiology/images/PMC3355691_U...
#
#                                           relationship  \
# 0    \nAI: The diagnosis is Obliteration of the lef...
# 1    \nAI: The UMLS semantic types describe the dia...
# 2    \nAI: The UMLS semantic types describe the dia...
# 3    \nAI: The UMLS semantic types describe the dia...
# 4    \nAI: The UMLS semantic types describe the dia...
# ..                                                 ...
# 500  \nAI: For the fluorescence angiography procedu...
# 501  \nAI: The UMLS semantic types describe the dis...
# 502  \nAI: Computed tomography revealing (Pathology...
# 503  \nAI: The UMLS semantic types describe the dia...
# 504  \nAI: The UMLS semantic types describe the dia...
#
#                                                summary
# 0    The diagnosis is Obliteration of the left maxi...
# 1    The UMLS semantic types describe the diagnosis...
# 2    The UMLS semantic types describe the diagnosis...
# 3    The UMLS semantic types describe the diagnosis...
# 4    The UMLS semantic types describe the diagnosis...
# ..                                                 ...
# 500  For the fluorescence angiography procedure (Di...
# 501  The UMLS semantic types describe the disease a...
# 502  Computed tomography revealing (Pathology) pneu...
# 503  The UMLS semantic types describe the diagnosis...
# 504  The UMLS semantic types describe the diagnosis...
#
# [505 rows x 5 columns]

# %%
for index, row in data.iterrows():
    image_path = row['image_path']
    if not os.path.exists(image_path):
        data.drop(index, inplace=True)
    else:
        try:
            image = Image.open(image_path)
        except Exception:
            data.drop(index, inplace=True)
        
# Reset the index after dropping rows
data.reset_index(drop=True, inplace=True)

data
# Out:
#              id                                            caption  \
# 0    ROCO_00002   Computed tomography scan in axial view showin...
# 1    ROCO_00003   Bacterial contamination occurred after comple...
# 2    ROCO_00004   The patient had residual paralysis of the han...
# 3    ROCO_00007   Plain abdomen x-ray: Multiple air levels at t...
# 4    ROCO_00008   A 3-year-old child with visual difficulties. ...
# ..          ...                                                ...
# 500  ROCO_00651   Fig. 5Fluorescein angiography: early hyperflu...
# 501  ROCO_00652   Transverse CT thorax image at the level of th...
# 502  ROCO_00653   Computed tomography revealing right upper-lun...
# 503  ROCO_00654   Lateral fluoroscopic view in a 77-year-old os...
# 504  ROCO_00655   Retrograde ureterogram reveals complete urete...
#
#                                             image_path  \
# 0    ./all_data/train/radiology/images/PMC4083729_A...
# 1    ./all_data/train/radiology/images/PMC2837471_I...
# 2    ./all_data/train/radiology/images/PMC2505281_1...
# 3    ./all_data/train/radiology/images/PMC4917066_a...
# 4    ./all_data/train/radiology/images/PMC4805615_1...
# ..                                                 ...
# 500  ./all_data/train/radiology/images/PMC5052491_J...
# 501  ./all_data/train/radiology/images/PMC4751134_j...
# 502  ./all_data/train/radiology/images/PMC5585904_1...
# 503  ./all_data/train/radiology/images/PMC3119972_A...
# 504  ./all_data/train/radiology/images/PMC3355691_U...
#
#                                           relationship  \
# 0    \nAI: The diagnosis is Obliteration of the lef...
# 1    \nAI: The UMLS semantic types describe the dia...
# 2    \nAI: The UMLS semantic types describe the dia...
# 3    \nAI: The UMLS semantic types describe the dia...
# 4    \nAI: The UMLS semantic types describe the dia...
# ..                                                 ...
# 500  \nAI: For the fluorescence angiography procedu...
# 501  \nAI: The UMLS semantic types describe the dis...
# 502  \nAI: Computed tomography revealing (Pathology...
# 503  \nAI: The UMLS semantic types describe the dia...
# 504  \nAI: The UMLS semantic types describe the dia...
#
#                                                summary
# 0    The diagnosis is Obliteration of the left maxi...
# 1    The UMLS semantic types describe the diagnosis...
# 2    The UMLS semantic types describe the diagnosis...
# 3    The UMLS semantic types describe the diagnosis...
# 4    The UMLS semantic types describe the diagnosis...
# ..                                                 ...
# 500  For the fluorescence angiography procedure (Di...
# 501  The UMLS semantic types describe the disease a...
# 502  Computed tomography revealing (Pathology) pneu...
# 503  The UMLS semantic types describe the diagnosis...
# 504  The UMLS semantic types describe the diagnosis...
#
# [505 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split

# Split data into train, test, and valid datasets
train_data, valid_test_data = train_test_split(data, test_size=test_valid_percentage/100, random_state=random_state)
valid_data, test_data = train_test_split(valid_test_data, test_size=0.5, random_state=random_state)

# Reset index
train_data = train_data.reset_index(drop=True)
valid_data = valid_data.reset_index(drop=True)
test_data = test_data.reset_index(drop=True)

# %%
print("Train data shape: ", train_data.shape)
print("Valid data shape: ", valid_data.shape)
print("Test data shape: ", test_data.shape)
# Out:
# Train data shape:  (353, 5)
# Valid data shape:  (76, 5)
# Test data shape:  (76, 5)

# %%
# Select n% of data
train_data = train_data.sample(frac=train_data_percentage/100, random_state=random_state)
valid_data = valid_data.sample(frac=valid_data_percentage/100, random_state=random_state)
test_data = test_data.sample(frac=test_data_percentage/100, random_state=random_state)

# %%
from datasets import Dataset, DatasetDict

# Convert DataFrame to Hugging Face dataset dictionary format
train_data_dict = Dataset.from_pandas(train_data)
valid_data_dict = Dataset.from_pandas(valid_data)
test_data_dict = Dataset.from_pandas(test_data)

dataset_dict = DatasetDict({
    'train': train_data_dict,
    'validation': valid_data_dict,
    'test': test_data_dict
})

print(dataset_dict)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'caption', 'image_path', 'relationship', 'summary', '__index_level_0__'],
#         num_rows: 353
#     })
#     validation: Dataset({
#         features: ['id', 'caption', 'image_path', 'relationship', 'summary', '__index_level_0__'],
#         num_rows: 76
#     })
#     test: Dataset({
#         features: ['id', 'caption', 'image_path', 'relationship', 'summary', '__index_level_0__'],
#         num_rows: 76
#     })
# })

# %%
# from PIL import Image

# # text preprocessing step
# def tokenization_fn(captions, max_target_length):
#     """Run tokenization on captions."""
#     labels = tokenizer(captions, 
#                       padding="max_length", 
#                       max_length=max_target_length).input_ids

#     return labels

# # image preprocessing step
# def preprocess_images(image_paths):
#     processed_images = []
#     for image_path in image_paths:
#         image = Image.open(image_path)
#         if image.mode != "RGB":
#             image = image.convert("RGB")
#         processed_images.append(image)
#     return processed_images

# def feature_extraction_fn(image_paths, check_image=True):
#     if check_image:
#         images = preprocess_images(image_paths)
#     else:
#         images = [Image.open(image_file) for image_file in image_paths]

#     encoder_inputs = feature_extractor(images=images, return_tensors="np")

#     return encoder_inputs.pixel_values

# # def feature_extraction_fn(image_paths, check_image=True):
# #     """
# #     Run feature extraction on images
# #     If `check_image` is `True`, the examples that fails during `Image.open()` will be caught and discarded.
# #     Otherwise, an exception will be thrown.
# #     """
# #     model_inputs = {}

# #     if check_image:
# #         images = []
# #         to_keep = []
# #         for image_file in image_paths:
# #             try:
# #                 img = Image.open(image_file)
# #                 images.append(img)
# #                 to_keep.append(True)
# #             except Exception:
# #                 to_keep.append(False)
# #     else:
# #         images = [Image.open(image_file) for image_file in image_paths]

# #     encoder_inputs = feature_extractor(images=images, return_tensors="np")

# #     return encoder_inputs.pixel_values

# def preprocess_fn(examples, max_target_length, check_image = True):
#     """Run tokenization + image feature extraction"""
#     image_paths = examples['image_path']
#     captions = examples['caption']    
    
#     model_inputs = {}
#     # This contains image path column
#     model_inputs['labels'] = tokenization_fn(captions, max_target_length)
#     model_inputs['pixel_values'] = feature_extraction_fn(image_paths, check_image=check_image)

#     return model_inputs

# %%
class ImageCaptioningDataset(torch.utils.data.Dataset):
    def __init__(self, ds, ds_type, max_target_length):
        self.ds = ds
        self.max_target_length = max_target_length
        self.ds_type = ds_type

    def __getitem__(self, idx):
        image_path = self.ds[self.ds_type]['image_path'][idx]
        caption = self.ds[self.ds_type]['caption'][idx]
        model_inputs = dict()
        model_inputs['labels'] = self.tokenization_fn(caption, self.max_target_length)
        model_inputs['pixel_values'] = self.feature_extraction_fn(image_path)
        return model_inputs

    def __len__(self):
        return len(self.ds[self.ds_type])
    
    # text preprocessing step
    def tokenization_fn(self, caption, max_target_length):
        """Run tokenization on caption."""
        labels = tokenizer(caption, 
                          padding="max_length", 
                          max_length=max_target_length,
                          truncation=True).input_ids

        return labels

    # image preprocessing step
    def feature_extraction_fn(self, image_path):
        image = Image.open(image_path)
        if image.mode != "RGB":
            image = image.convert("RGB")

        encoder_inputs = feature_extractor(images=image, return_tensors="np")

        return encoder_inputs.pixel_values[0]
#         except Exception:
#             print(Exception)
#             return np.empty((0,))

# %%
# processed_dataset = dataset_dict.map(
#     function=preprocess_fn,
#     batched=True,
#     fn_kwargs={"max_target_length": 128},
#     remove_columns=dataset_dict['train'].column_names
# )

# %%
# processed_dataset

# %%
train_ds = ImageCaptioningDataset(dataset_dict, 'train', max_target_length)
eval_ds = ImageCaptioningDataset(dataset_dict, 'validation', max_target_length)
test_ds = ImageCaptioningDataset(dataset_dict, 'test', max_target_length)

# %% [markdown]
# ## Define seq2seq training argumentsPermalink

# %%
from transformers import Seq2SeqTrainer, Seq2SeqTrainingArguments

training_args = Seq2SeqTrainingArguments(
    predict_with_generate=True,
    evaluation_strategy="epoch",
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    output_dir="./image-captioning-output",
)
# Out:
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).

# %% [markdown]
# ## Define metric

# %%
import evaluate
metric = evaluate.load("rouge")

# %%
import numpy as np

ignore_pad_token_for_loss = True

def postprocess_text(preds, labels):
    preds = [pred.strip() for pred in preds]
    labels = [label.strip() for label in labels]

    # rougeLSum expects newline after each sentence
    preds = ["\n".join(nltk.sent_tokenize(pred)) for pred in preds]
    labels = ["\n".join(nltk.sent_tokenize(label)) for label in labels]

    return preds, labels

def compute_metrics(eval_preds):
    preds, labels = eval_preds
    if isinstance(preds, tuple):
        preds = preds[0]
    decoded_preds = tokenizer.batch_decode(preds, skip_special_tokens=True)
    if ignore_pad_token_for_loss:
        # Replace -100 in the labels as we can't decode them.
        labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    # Some simple post-processing
    decoded_preds, decoded_labels = postprocess_text(decoded_preds,
                                                     decoded_labels)

    result = metric.compute(predictions=decoded_preds,
                            references=decoded_labels,
                            use_stemmer=True)
    result = {k: round(v * 100, 4) for k, v in result.items()}
    prediction_lens = [
        np.count_nonzero(pred != tokenizer.pad_token_id) for pred in preds
    ]
    result["gen_len"] = np.mean(prediction_lens)
    return result

# %% [markdown]
# ## Training

# %%
from transformers import default_data_collator

# # instantiate trainer
# trainer = Seq2SeqTrainer(
#     model=model,
#     tokenizer=feature_extractor,
#     args=training_args,
#     compute_metrics=compute_metrics,
#     train_dataset=processed_dataset['train'],
#     eval_dataset=processed_dataset['validation'],
#     data_collator=default_data_collator,
# )

# instantiate trainer
trainer = Seq2SeqTrainer(
    model=model,
    tokenizer=feature_extractor,
    args=training_args,
    compute_metrics=compute_metrics,
    train_dataset=train_ds,
    eval_dataset=eval_ds,
    data_collator=default_data_collator,
)

#6799

# %%
trainer.train()
# Out:
# C:\Users\ACER\anaconda3\lib\site-packages\transformers\optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 353
#   Num Epochs = 3
#   Instantaneous batch size per device = 4
#   Total train batch size (w. parallel, distributed & accumulation) = 4
#   Gradient Accumulation steps = 1
#   Total optimization steps = 267
#   Number of trainable parameters = 239195904
#     <div>
#
#       <progress value='267' max='267' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [267/267 04:01, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.428813</td>
#       <td>12.810200</td>
#       <td>1.199000</td>
#       <td>9.519300</td>
#       <td>10.039000</td>
#       <td>18.763158</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.421340</td>
#       <td>19.044500</td>
#       <td>4.455000</td>
#       <td>16.463000</td>
#       <td>16.753600</td>
#       <td>18.657895</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.422779</td>
#       <td>18.796100</td>
#       <td>3.895700</td>
#       <td>16.475600</td>
#       <td>16.673600</td>
#       <td>18.486842</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 76
#   Batch size = 4
# ***** Running Evaluation *****
#   Num examples = 76
#   Batch size = 4
# ***** Running Evaluation *****
#   Num examples = 76
#   Batch size = 4
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=267, training_loss=0.5580083725604226, metrics={'train_runtime': 248.5096, 'train_samples_per_second': 4.261, 'train_steps_per_second': 1.074, 'total_flos': 1.9111126069621555e+17, 'train_loss': 0.5580083725604226, 'epoch': 3.0})

# %%
#trainer.train("./image-captioning-output\checkpoint-6500")

# %%
trainer.save_model("./new_image-captioning-output-without-llm")
tokenizer.save_pretrained("./new_image-captioning-output-without-llm")
# Out:
# Saving model checkpoint to ./new_image-captioning-output-without-llm
# Configuration saved in ./new_image-captioning-output-without-llm\config.json
# Model weights saved in ./new_image-captioning-output-without-llm\pytorch_model.bin
# Feature extractor saved in ./new_image-captioning-output-without-llm\preprocessor_config.json
# tokenizer config file saved in ./new_image-captioning-output-without-llm\tokenizer_config.json
# Special tokens file saved in ./new_image-captioning-output-without-llm\special_tokens_map.json
# ('./new_image-captioning-output-without-llm\\tokenizer_config.json',
#  './new_image-captioning-output-without-llm\\special_tokens_map.json',
#  './new_image-captioning-output-without-llm\\vocab.json',
#  './new_image-captioning-output-without-llm\\merges.txt',
#  './new_image-captioning-output-without-llm\\added_tokens.json',
#  './new_image-captioning-output-without-llm\\tokenizer.json')

# %%
# Get predictions from the model
predictions = trainer.predict(test_ds)

# Process and evaluate the predictions
preds = predictions.predictions
labels = predictions.label_ids

# Post-process the predictions and labels
decoded_preds = tokenizer.batch_decode(preds, skip_special_tokens=True)
decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

# Calculate evaluation metrics
from nltk.translate.bleu_score import sentence_bleu, corpus_bleu
bleu_scores = []

# Print the actual captions and predicted captions
for actual_caption, predicted_caption in zip(decoded_labels, decoded_preds):
    actual_caption = actual_caption.split("</s>")[0]
    predicted_caption = predicted_caption.split("</s>")[0]
    bleu_score = sentence_bleu([actual_caption.split()], predicted_caption.split())
    bleu_scores.append(bleu_score)
    print("Actual Caption:", actual_caption)
    print("Predicted Caption:", predicted_caption)
    print("Blue score: ", bleu_score)
    print("--------------")

average_bleu_score = sum(bleu_scores) / len(bleu_scores)

# Print average BLEU score
print("Average BLEU score:", average_bleu_score)
# Out:
# ***** Running Prediction *****
#   Num examples = 76
#   Batch size = 4
# Actual Caption:  Diffusion-weighted image shows acute infarct in left parieto-occipital area
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fat in the right abdomen.
#
# Blue score:  1.0832677820940877e-231
# --------------
# Actual Caption:  Transverse view of lung using computed tomography. Leukemic infiltration is seen.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of lymph nodes in the right abdomen.
#
# Blue score:  8.972141065609098e-232
# --------------
# Actual Caption:  Facial skull radiograph. Note sclerosis of the orbits and sphenoid bones resulting in “Harlequin mask appearance’’
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fat and a large amount of fluid in
# Blue score:  4.905470711005226e-155
# --------------
# Actual Caption:  MRI showing that the mass was greatly enhanced, with a clear portion in the nearby tissues.MRI showing that the mass was greatly enhanced, with a clear portion in the nearby tissues
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of lymph nodes in the right abdomen.
#
# Blue score:  2.410561475407062e-155
# --------------
# Actual Caption:  Axial fat-suppressed T2-weighted MRI showed subcutaneous oedema and interfascial plane swelling at the right gluteal region, as well as a subcutaneous fibrogranulation tract (arrow) that corresponded to the acupuncture insertion tract.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fat and a large amount of fluid in
# Blue score:  6.10673374785031e-232
# --------------
# Actual Caption:  Coronal T1-weighted magnetic resonance imaging showing a tumor with homogenous low-signal intensity and well-defined margins.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fat and a large mass of fluid in
# Blue score:  1.0377133938315695e-231
# --------------
# Actual Caption:  MRI (cross-sectional view) (arrow) showing T2-weighted hypointense lesion within the pancreatic body
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fat and a large amount of fluid in
# Blue score:  8.726094729337945e-232
# --------------
# Actual Caption:  CECT abdomen showing the lesion.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of lymph nodes (arrows) in the
# Blue score:  1.0832677820940877e-231
# --------------
# Actual Caption:  A repeated PET/CT reveals disseminated multiple bony lytic lesions with increased FDG uptake.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fluid in the abdomen.
#
# Blue score:  9.257324954728539e-232
# --------------
# Actual Caption:  CT showing gutta percha point communicating with the periapical area
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fluid in the abdomen.
#
# Blue score:  1.1008876702055895e-231
# --------------
# Actual Caption:  The intraoral radiograph revealed a complete fill of the intrabony defect and a significant improvement in vertical dimension of the resorbed ridge. At 2 years after insertion of the implants, a stable periimplant condition can be observed
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fat and fat-filled lymph nodes.
# Blue score:  1.525282891102224e-155
# --------------
# Actual Caption:  A 30-year-old-woman with genital tuberculosis. Hysterosalpingogram shows a beaded appearance at the right and left fallopian tubes associated with bilateral tubal occlusion (arrows). There is mild irregularity of the uterine cavity outline
#
# Predicted Caption:  A patient with a history of multiple sclerosis (arrow) with a history of multiple sclerosis (arrow
# Blue score:  5.0110224342549755e-232
# --------------
# Actual Caption:  Upper gastrointestinal series. Polypous masses in the bulb and the prepyloric part of the stomach
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fat and a large mass of fluid in
# Blue score:  4.905470711005226e-155
# --------------
# Actual Caption:  Color Doppler ultrasound image demonstrates multiple tortuous venous structures in the hepatic hilum, keeping with the cavernomatous transformation of the portal vein.
#
# Predicted Caption:  A CT scan of the abdomen shows a large, irregular mass in the abdomen.
#
# Blue score:  3.8570794972192865e-155
# --------------
# Actual Caption:  Contrast-enhanced axial CT brainMultiple solid enhancing cortical lesions with dense gyriform calcifications are seen in both cerebral hemispheres. CT- computed tomography
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of lymph nodes in the right abdomen.
#
# Blue score:  8.432700096708783e-232
# --------------
# Actual Caption:  Coronal T2-weighted MRI shows a lack of normal signal void of the left internal carotid artery.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of lymph nodes in the right abdomen.
#
# Blue score:  6.53175655370481e-155
# --------------
# Actual Caption:  Castleman disease. Contrast-enhanced chest CT scan shows matted lymphadenopathy (arrows) formed by confluence of inhomogeneously enhancing enlarged lymph nodes confined to anterior mediastinum.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of lymph nodes (arrows) in the
# Blue score:  4.733120686361622e-155
# --------------
# Actual Caption:  The tibial tubercle–trochlear groove (TT-TG) distance is determined by a line from the most anterior point of the tibial tuberosity to the line running through the trochlear groove (orange). Modified from Cooney et al28 with permission.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fluid in the abdomen.
#
# Blue score:  1.3665329728945115e-155
# --------------
# Actual Caption:  Computed tomography (CT) guided needle biopsy of the left upper lobe lesion.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fat and a large amount of fluid in
# Blue score:  4.124992736016442e-155
# --------------
# Actual Caption:  Panoramic radiograph showing extensive radio-opaque lesion with well-defined corticated border.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fat and a large mass of fluid in
# Blue score:  0
# --------------
# Actual Caption:  Magnetic resonance angiography image showing almost complete thrombosis of the basilar artery (arrow). This is an extension from the vertebral artery dissection and thrombosis.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fluid in the abdomen.
#
# Blue score:  2.830225349922215e-155
# --------------
# Actual Caption:  Focal steatosis of the liver parenchyma
#
# Predicted Caption:  A CT scan of the abdomen shows a large, irregular mass in the abdomen.
#
# Blue score:  4.829607837557235e-155
# --------------
# Actual Caption:  Proton-density, fat saturation coronal sequence demonstrating the bony prominence at the femoral head-neck junction (arrow). Also evident is a subtle, adjacent articular cartilage signal irregularity consistent with chondrosis.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fat and a large amount of fluid in
# Blue score:  7.151247323066152e-232
# --------------
# Actual Caption:  Upper contrast study gastric distension with no opacification of the bulb or the duodenum
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fat and a large amount of fluid in
# Blue score:  4.124992736016442e-155
# --------------
# Actual Caption:  Apical four-chamber view showing large vegetation attached with the tricuspid valve leaflet
#
# Predicted Caption:  A CT scan of the abdomen shows a large, irregular mass in the right abdomen.
#
# Blue score:  9.257324954728539e-232
# --------------
# Actual Caption:  Coupe axiale d’un scanner abdominal passant par le foie après injection du PC
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of lymph nodes in the right abdomen.
#
# Blue score:  0
# --------------
# Actual Caption:  Barium swallow demonstrating the obstructive appearance of the GCT.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fluid in the abdomen.
#
# Blue score:  5.157006819435075e-155
# --------------
# Actual Caption:  SANT of the spleen: 99mTc-sulfur colloid scan findings. SPECT CT shows normal tracer activity within the liver and spleen with essentially no activity within the splenic lesion, confirming the absence of reticuloendothelial elements within this abnormality.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of lymph nodes (arrows) in the
# Blue score:  1.7661427907428113e-155
# --------------
# Actual Caption:  AP radiograph showing the displaced hip prosthesis into the pelvic cavity.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fat and a large mass of fluid in
# Blue score:  8.726094729337945e-232
# --------------
# Actual Caption:  Axial T2-weighted image of MRI showing hyperintensity at the center and hypointensity at periphery, suggesting peripheral tumor location with central intratumoral hematoma. MRI = magnetic resonance imaging.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of lymph nodes (arrows) in the
# Blue score:  5.447012482354515e-232
# --------------
# Actual Caption:  X-ray control of calcaneus drilling
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fluid in the abdomen.
#
# Blue score:  9.257324954728539e-232
# --------------
# Actual Caption:  Radiographie montrant une ostéolyse des genoux et une périostite chez un 2 mois et 22 jours pris en charge pour syphilis congénitale révélée par une fracture spontanée
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fat and a large mass of lymph nodes
# Blue score:  0
# --------------
# Actual Caption:  A chest radiograph shows reticulonodular shadowing with bilateral apical lung fibrosis and high density nodules in coal workers pneumoconiosis
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fat and a large amount of fluid in
# Blue score:  1.2340561512781763e-231
# --------------
# Actual Caption:  CT showing a large multilobulated cystic collection extending to the pelvis.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fat and a large amount of fluid in
# Blue score:  4.905470711005226e-155
# --------------
# Actual Caption:   Preoperative computed tomography scan: lipid formation without any capsular structure in the perineum.
#
# Predicted Caption:  A CT scan of the abdomen shows a large, irregular mass in the right abdomen.
#
# Blue score:  4.65988169467104e-155
# --------------
# Actual Caption:  Postoperative anteroposterior radiograph after bilateral cemented arthroplasty.
#
# Predicted Caption:  A CT scan of the abdomen shows a large, irregular, irregular, and irregular mass in the
# Blue score:  0
# --------------
# Actual Caption:  Radiographs show healing of the fracture at 53 days postoperatively.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fat and a large mass of fluid in
# Blue score:  4.124992736016442e-155
# --------------
# Actual Caption:  High left parasternal projection. Blue color is used to mark the flow in the descending aorta (AoD), red color to mark the upward movement in the vein located leftward from the aorta which drains into the left venous angle (V). Additional markings: LB – left brachiocephalic vein
#
# Predicted Caption:  A CT scan of the abdomen shows a large, irregular mass in the right abdomen.
#
# Blue score:  6.108053199305489e-156
# --------------
# Actual Caption:  Coronal view of a temporal maximum intensity projection visualizing part of the middle cerebral artery including the M1, M2 and M3 segments. Intensity differences from proximal to distal in a nonaffected vessel can reach up to 450 HU and higher. Vessel occlusions, vessel wall calcifications, collateral flow, clip and stent artifacts have a large influence on the continuity of intensity values along the vessel.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of lymph nodes (arrows) in the
# Blue score:  3.649790769429644e-156
# --------------
# Actual Caption:  Chest X-ray, PA, showing the position of the gun nails
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fat and a large amount of fluid in
# Blue score:  4.124992736016442e-155
# --------------
# Actual Caption:  Concentric reduction of both femoral heads after close reduction.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fat and a large amount of fluid in
# Blue score:  8.726094729337945e-232
# --------------
# Actual Caption:  CT image showing the hydatic cyst that PAIR was performed.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of lymph nodes in the right abdomen.
#
# Blue score:  1.0669733992029681e-231
# --------------
# Actual Caption:  Computed tomography revealing right upper-lung pneumonia, the air–fluid level, and septic embolism
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fluid in the abdomen.
#
# Blue score:  9.257324954728539e-232
# --------------
# Actual Caption:  Computed tomography with contrast medium (portal phase). The presence of abscess was suspected at the right lobe of the liver.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of lymph nodes in the right abdomen.
#
# Blue score:  5.475071398197871e-155
# --------------
# Actual Caption:  Abdominal CT image showing marked cecal dilatation.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fat and a large amount of fluid in
# Blue score:  8.726094729337945e-232
# --------------
# Actual Caption:  Before PDT, fluorescein angiography shows a predominantly classic subfoveal CNV.Abbreviations: CNV, choroidal neovascularization; PDT, photodynamic therapy.
#
# Predicted Caption:  The patient was placed in a ventilator with a ventilator attached to the right side
# Blue score:  8.660292157856052e-232
# --------------
# Actual Caption:  Abdomen Doppler ultrasound. A well-defined hypoechoic area (~53×39 mm) at the quadrate lobe of the liver, showing that the internal echo of the mass was heterogeneous.
#
# Predicted Caption:  A CT scan of the abdomen shows a large, irregular mass in the abdomen.
#
# Blue score:  2.5771782455835985e-155
# --------------
# Actual Caption:  An abdominal X-ray showing a diffuse opaque area in the upper abdomen without a gastrointestinal gas shadow; this finding was accompanied by a downward dislocation of the transverse colon
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fat and a large amount of fluid in
# Blue score:  3.207210452816087e-155
# --------------
# Actual Caption:  A sagittal fat-suppressed proton density–weighted image of the left hip (the same patient as Figure 7) depicts the avulsion injury involving both the direct (arrow) and the indirect (arrowhead) heads of the rectus femoris.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fat and a large mass of fluid in
# Blue score:  2.3552885760859895e-155
# --------------
# Actual Caption:  Micro-CT image of the rat tibias with the titanium implants.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fat and a large mass of fluid in
# Blue score:  4.124992736016442e-155
# --------------
# Actual Caption:  At the end of treatment. Posttreatment PET-CT scan showing a borderline enlarged left supraclavicular lymph node (white arrow) with moderate to intense FDG activity (SUVmax 8.4). In the absence of any significant adenopathy elsewhere in the body, this was deemed to be of reactive nature.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fat and a large mass of fluid in
# Blue score:  3.6124073832715126e-232
# --------------
# Actual Caption:  Computed tomography cross-section of the pelvis showing right buttock inflammatory changes and a subcutaneous pocket of air lateral to the natal cleft. The pocket of air corresponds to the described abscess.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fat and a large mass of fluid in
# Blue score:  3.4329679506311515e-155
# --------------
# Actual Caption:  Orthopantomograph (OPG) showing radiolucency extending from 13 to 17 regions with 16 root resorption and root displacement in 17, 14
#
# Predicted Caption:  A CT scan of the abdomen shows a large, irregular mass in the abdomen.
#
# Blue score:  6.135502086137096e-232
# --------------
# Actual Caption:  Retrograde urethrogram showing the fistulous tract (arrow) communicating with the ventral part of the anterior urethra.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fat and a large mass of lymph nodes
# Blue score:  4.124992736016442e-155
# --------------
# Actual Caption:  Navigated 3D SPACE image demonstrated discrete proximal aortic arch narrowing in a 6 month old with a history of arch hypoplasia and coarctation of the aorta who previously underwent an arch augmentation.
#
# Predicted Caption:  The left ventricle of the right ventricle is enlarged.
#
# Blue score:  4.72860366544183e-156
# --------------
# Actual Caption:  Computed tomography scan shows no evidence of tumor recurrence in the right parotid region at 18 months after the third operation.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fluid in the abdomen.
#
# Blue score:  4.110904727268676e-155
# --------------
# Actual Caption:  Chest X-ray findings. Chest radiograph revealed an engorged pulmonary trunk with an abrupt cutoff of pulmonary vascularity in the distal portions bilaterally, indicative of the "Westermark sign" (arrows).
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fat and a large amount of fluid in
# Blue score:  3.054655570640395e-155
# --------------
# Actual Caption:  Panoramic view showing multiple impacted permanent and supernumerary teeth, hypoplastic maxillary sinus and slender coronoid process.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fat and a large amount of fluid in
# Blue score:  8.726094729337945e-232
# --------------
# Actual Caption:   Computed tomography axial section after injection of contrast medium in parenchymal time showing a large thrombus in the left renal vein extending from the segmental renal veins to the inferior vena cava, complicated by cortical infarction.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of lymph nodes (arrows) in the
# Blue score:  2.0209083318129296e-155
# --------------
# Actual Caption:  Radiographic observations at the time of the initial consultation showing an osteolytic lesion with an osteosclerotic change to the femoral neck (arrows).
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fat and a large mass of fluid in
# Blue score:  3.5224949176933916e-155
# --------------
# Actual Caption:  Simple abdominal X-ray presents multiple dilated small bowel loops.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fat and a large amount of fluid in
# Blue score:  0
# --------------
# Actual Caption:  Soft tissue Bankart lesion with a tear of the anterior inferior labrum and an adjacent, small, full-thickness mild (<25%) chondral defect over the anterior inferior glenoid (arrow) on an axial proton density sequence.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of lymph nodes in the right abdomen.
#
# Blue score:  2.0267362712009616e-155
# --------------
# Actual Caption:  Magnetic resonance of abdomen showing two lesions within the right lobe of the liver along the peripheral surface (black arrows).
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fluid in the abdomen.
#
# Blue score:  4.198508780749403e-155
# --------------
# Actual Caption:  Image of the TMJ shows the morphology of the TMJ in an asymptomatic volunteer.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fluid in the abdomen.
#
# Blue score:  6.13274920178966e-155
# --------------
# Actual Caption:  Motility Assay.Figure shows motility of the E. coli K12 MG1655 wild type (wt) and strains harboring integrations in the target loci of the flagellar region 1 (flgA (flgAi), flgF (flgFi), flgG (flgGi), flgI (flgIi), and flgJ (flgJi)). 2 μl of the overnight E. coli cultures (OD600 of 1.0) were inoculated in the middle of the motility plates and incubated for 4–6 hours at 37°C.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fat and a large amount of fluid in
# Blue score:  5.282603383749957e-156
# --------------
# Actual Caption:  Lateral-view radiograph of a wrist that underwent arthrodesis with minimal fixation. Note the dorsal bone plate and the free carpometacarpal joints. The Kirschner wires that had been holding the bone plate and radiocarpal joint have been removed.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fat and a large amount of fluid in
# Blue score:  4.7851774069309084e-232
# --------------
# Actual Caption:  Intraoral periapical radiograph taken to check position of the mini-implant.
#
# Predicted Caption:  A CT scan of the abdomen shows a large, irregular mass in the right abdomen.
#
# Blue score:  4.65988169467104e-155
# --------------
# Actual Caption:  Right-sided metatarsal in dorsoplantar projection.Cow. Age group IV—cattle 4–8 years. (a) Narrow symphysis that is (b) indistinct from the bone surface.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fat and a large mass of fluid in
# Blue score:  9.340329853840331e-232
# --------------
# Actual Caption:  Postoperative panoramic radiograph after surgery. The costochondral graft was adjusted to the left condyle area and secured on the left mandibular ramus by five bicortical screws for rigid internal fixation
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fat and a large mass of fluid in
# Blue score:  5.8162594989391954e-232
# --------------
# Actual Caption:  AbdominoPelvic MRI showing a large mass containing fetus in right adnexa in close contact with uterus.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fat and a large amount of fluid in
# Blue score:  2.3522845047145266e-78
# --------------
# Actual Caption:  An angiographic view of a patient whose coarctation was removed surgically by the procedure of subclavian flap angioplasty
#
# Predicted Caption:  A CT scan of the abdomen shows a large, irregular mass in the right abdomen.
#
# Blue score:  9.97486269044271e-232
# --------------
# Actual Caption:  Hypotonic duodenography showing a contrast media-positive elevated lesion in the center of the duodenal bulb.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fluid in the abdomen.
#
# Blue score:  6.968148412761692e-155
# --------------
# Actual Caption:  Intraoral periapical radiograph of the patient depicting unusual morphology of mandibular left second premolar
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fat and a large mass of fluid in
# Blue score:  4.565054879844424e-155
# --------------
# Actual Caption:  MRI revealed a huge mass adjacent to the first and second lumbar vertebrae with extension into the spinal canal.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fat and a large mass of lymph nodes
# Blue score:  1.2340561512781763e-231
# --------------
# Actual Caption:  The vertical distance from the alveolar ridge to the most inferior sinus floor at the projected implant placement site was 7.45 mm in this specific panoramic radiograph before the implant surgery (black line).
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of fat and a large mass of fat mass
# Blue score:  4.176509397770322e-232
# --------------
# Actual Caption:  CT head with IV contrast with an arrow that indicates cerebral venous sinus thrombosis.
#
# Predicted Caption:  A CT scan of the abdomen shows a large mass of lymph nodes in the right abdomen.
#
# Blue score:  8.972141065609098e-232
# --------------
# Average BLEU score: 3.095111190413851e-80
# C:\Users\ACER\anaconda3\lib\site-packages\nltk\translate\bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# C:\Users\ACER\anaconda3\lib\site-packages\nltk\translate\bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# C:\Users\ACER\anaconda3\lib\site-packages\nltk\translate\bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)

# %% [markdown]
# ## With knowledge

# %%
from transformers import VisionEncoderDecoderModel, AutoTokenizer, AutoFeatureExtractor

image_encoder_model = "google/vit-base-patch16-224-in21k"
text_decode_model = "gpt2"

model = VisionEncoderDecoderModel.from_encoder_decoder_pretrained(image_encoder_model, text_decode_model)

# image feature extractor
feature_extractor = AutoFeatureExtractor.from_pretrained(image_encoder_model)
# text tokenizer
tokenizer = AutoTokenizer.from_pretrained(text_decode_model)

# GPT2 only has bos/eos tokens but not decoder_start/pad tokens
tokenizer.pad_token = tokenizer.eos_token

# update the model config
model.config.eos_token_id = tokenizer.eos_token_id
model.config.decoder_start_token_id = tokenizer.bos_token_id
model.config.pad_token_id = tokenizer.pad_token_id
# Out:
# loading configuration file config.json from cache at C:\Users\ACER/.cache\huggingface\hub\models--google--vit-base-patch16-224-in21k\snapshots\7cbdb7ee3a6bcdf99dae654893f66519c480a0f8\config.json
# Model config ViTConfig {
#   "_name_or_path": "google/vit-base-patch16-224-in21k",
#   "architectures": [
#     "ViTModel"
#   ],
#   "attention_probs_dropout_prob": 0.0,
#   "encoder_stride": 16,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.0,
#   "hidden_size": 768,
#   "image_size": 224,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "model_type": "vit",
#   "num_attention_heads": 12,
#   "num_channels": 3,
#   "num_hidden_layers": 12,
#   "patch_size": 16,
#   "qkv_bias": true,
#   "transformers_version": "4.24.0"
# }
#
# loading weights file pytorch_model.bin from cache at C:\Users\ACER/.cache\huggingface\hub\models--google--vit-base-patch16-224-in21k\snapshots\7cbdb7ee3a6bcdf99dae654893f66519c480a0f8\pytorch_model.bin
# All model checkpoint weights were used when initializing ViTModel.
#
# All the weights of ViTModel were initialized from the model checkpoint at google/vit-base-patch16-224-in21k.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use ViTModel for predictions without further training.
# loading configuration file config.json from cache at C:\Users\ACER/.cache\huggingface\hub\models--gpt2\snapshots\e7da7f221d5bf496a48136c0cd264e630fe9fcc8\config.json
# Model config GPT2Config {
#   "_name_or_path": "gpt2",
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.24.0",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# Initializing gpt2 as a decoder model. Cross attention layers are added to gpt2 and randomly initialized if gpt2's architecture allows for cross attention layers.
# loading weights file pytorch_model.bin from cache at C:\Users\ACER/.cache\huggingface\hub\models--gpt2\snapshots\e7da7f221d5bf496a48136c0cd264e630fe9fcc8\pytorch_model.bin
# All model checkpoint weights were used when initializing GPT2LMHeadModel.
#
# Some weights of GPT2LMHeadModel were not initialized from the model checkpoint at gpt2 and are newly initialized: ['h.9.crossattention.c_proj.weight', 'h.8.crossattention.bias', 'h.3.crossattention.c_proj.weight', 'h.2.crossattention.c_attn.weight', 'h.8.crossattention.c_attn.weight', 'h.8.ln_cross_attn.weight', 'h.6.crossattention.c_proj.weight', 'h.3.crossattention.masked_bias', 'h.1.crossattention.c_attn.weight', 'h.2.crossattention.q_attn.weight', 'h.0.crossattention.c_attn.weight', 'h.9.crossattention.c_attn.weight', 'h.7.crossattention.c_proj.bias', 'h.7.crossattention.bias', 'h.4.crossattention.bias', 'h.9.crossattention.c_proj.bias', 'h.1.crossattention.masked_bias', 'h.6.crossattention.bias', 'h.5.crossattention.bias', 'h.6.crossattention.masked_bias', 'h.3.crossattention.bias', 'h.1.crossattention.c_proj.weight', 'h.8.crossattention.c_proj.weight', 'h.7.crossattention.c_attn.weight', 'h.10.crossattention.masked_bias', 'h.11.crossattention.q_attn.weight', 'h.10.crossattention.c_proj.bias', 'h.8.crossattention.masked_bias', 'h.0.crossattention.q_attn.weight', 'h.10.crossattention.c_attn.weight', 'h.0.crossattention.c_proj.weight', 'h.5.crossattention.masked_bias', 'h.9.ln_cross_attn.weight', 'h.7.crossattention.q_attn.weight', 'h.4.crossattention.c_proj.weight', 'h.2.crossattention.masked_bias', 'h.10.ln_cross_attn.weight', 'h.1.ln_cross_attn.weight', 'h.1.crossattention.c_proj.bias', 'h.3.ln_cross_attn.weight', 'h.10.crossattention.q_attn.weight', 'h.2.crossattention.bias', 'h.3.crossattention.q_attn.weight', 'h.2.ln_cross_attn.weight', 'h.4.crossattention.masked_bias', 'h.0.crossattention.c_proj.bias', 'h.1.crossattention.bias', 'h.8.crossattention.c_proj.bias', 'h.6.crossattention.c_proj.bias', 'h.10.crossattention.bias', 'h.11.crossattention.c_proj.weight', 'h.7.crossattention.c_proj.weight', 'h.0.crossattention.masked_bias', 'h.7.ln_cross_attn.weight', 'h.11.crossattention.bias', 'h.5.crossattention.q_attn.weight', 'h.0.crossattention.bias', 'h.9.crossattention.masked_bias', 'h.11.crossattention.c_attn.weight', 'h.6.ln_cross_attn.weight', 'h.11.crossattention.masked_bias', 'h.7.crossattention.masked_bias', 'h.9.crossattention.q_attn.weight', 'h.8.crossattention.q_attn.weight', 'h.4.crossattention.c_attn.weight', 'h.4.crossattention.q_attn.weight', 'h.2.crossattention.c_proj.bias', 'h.1.crossattention.q_attn.weight', 'h.4.crossattention.c_proj.bias', 'h.5.crossattention.c_proj.bias', 'h.3.crossattention.c_attn.weight', 'h.11.ln_cross_attn.weight', 'h.10.crossattention.c_proj.weight', 'h.4.ln_cross_attn.weight', 'h.5.crossattention.c_proj.weight', 'h.5.ln_cross_attn.weight', 'h.0.ln_cross_attn.weight', 'h.3.crossattention.c_proj.bias', 'h.11.crossattention.c_proj.bias', 'h.5.crossattention.c_attn.weight', 'h.6.crossattention.q_attn.weight', 'h.9.crossattention.bias', 'h.2.crossattention.c_proj.weight', 'h.6.crossattention.c_attn.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Setting `config.is_decoder=True` and `config.add_cross_attention=True` for decoder_config
# loading configuration file preprocessor_config.json from cache at C:\Users\ACER/.cache\huggingface\hub\models--google--vit-base-patch16-224-in21k\snapshots\7cbdb7ee3a6bcdf99dae654893f66519c480a0f8\preprocessor_config.json
# loading configuration file config.json from cache at C:\Users\ACER/.cache\huggingface\hub\models--google--vit-base-patch16-224-in21k\snapshots\7cbdb7ee3a6bcdf99dae654893f66519c480a0f8\config.json
# Model config ViTConfig {
#   "_name_or_path": "google/vit-base-patch16-224-in21k",
#   "architectures": [
#     "ViTModel"
#   ],
#   "attention_probs_dropout_prob": 0.0,
#   "encoder_stride": 16,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.0,
#   "hidden_size": 768,
#   "image_size": 224,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "model_type": "vit",
#   "num_attention_heads": 12,
#   "num_channels": 3,
#   "num_hidden_layers": 12,
#   "patch_size": 16,
#   "qkv_bias": true,
#   "transformers_version": "4.24.0"
# }
#
# Feature extractor ViTFeatureExtractor {
#   "do_normalize": true,
#   "do_resize": true,
#   "feature_extractor_type": "ViTFeatureExtractor",
#   "image_mean": [
#     0.5,
#     0.5,
#     0.5
#   ],
#   "image_std": [
#     0.5,
#     0.5,
#     0.5
#   ],
#   "resample": 2,
#   "size": 224
# }
#
# Could not locate the tokenizer configuration file, will try to use the model config instead.
# loading configuration file config.json from cache at C:\Users\ACER/.cache\huggingface\hub\models--gpt2\snapshots\e7da7f221d5bf496a48136c0cd264e630fe9fcc8\config.json
# Model config GPT2Config {
#   "_name_or_path": "gpt2",
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.24.0",
#   "use_cache": true,
#   "vocab_size": 50257
# }
# loading file vocab.json from cache at C:\Users\ACER/.cache\huggingface\hub\models--gpt2\snapshots\e7da7f221d5bf496a48136c0cd264e630fe9fcc8\vocab.json
# loading file merges.txt from cache at C:\Users\ACER/.cache\huggingface\hub\models--gpt2\snapshots\e7da7f221d5bf496a48136c0cd264e630fe9fcc8\merges.txt
# loading file tokenizer.json from cache at C:\Users\ACER/.cache\huggingface\hub\models--gpt2\snapshots\e7da7f221d5bf496a48136c0cd264e630fe9fcc8\tokenizer.json
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at None
# loading file tokenizer_config.json from cache at None
# loading configuration file config.json from cache at C:\Users\ACER/.cache\huggingface\hub\models--gpt2\snapshots\e7da7f221d5bf496a48136c0cd264e630fe9fcc8\config.json
# Model config GPT2Config {
#   "_name_or_path": "gpt2",
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.24.0",
#   "use_cache": true,
#   "vocab_size": 50257
# }

# %%
class ImageCaptioningDatasetWithKnowledge(torch.utils.data.Dataset):
    def __init__(self, ds, ds_type, max_target_length):
        self.ds = ds
        self.max_target_length = max_target_length
        self.ds_type = ds_type

    def __getitem__(self, idx):
        image_path = self.ds[self.ds_type]['image_path'][idx]
        caption = self.ds[self.ds_type]['caption'][idx]
        summary = self.ds[self.ds_type]['summary'][idx]
        model_inputs = dict()
        model_inputs['labels'] = self.tokenization_fn(f'{caption} </s> {summary}', self.max_target_length)
        model_inputs['pixel_values'] = self.feature_extraction_fn(image_path)
        return model_inputs

    def __len__(self):
        return len(self.ds[self.ds_type])
    
    # text preprocessing step
    def tokenization_fn(self, caption, max_target_length):
        """Run tokenization on caption."""
        labels = tokenizer(caption, 
                          padding="max_length", 
                          max_length=max_target_length,
                          truncation=True).input_ids

        return labels

    # image preprocessing step
    def feature_extraction_fn(self, image_path):
        image = Image.open(image_path)
        if image.mode != "RGB":
            image = image.convert("RGB")

        encoder_inputs = feature_extractor(images=image, return_tensors="np")

        return encoder_inputs.pixel_values[0]
#         except Exception:
#             print(Exception)
#             return np.empty((0,))

# %%
train_ds = ImageCaptioningDatasetWithKnowledge(dataset_dict, 'train', max_target_length)
eval_ds = ImageCaptioningDatasetWithKnowledge(dataset_dict, 'validation', max_target_length)
test_ds = ImageCaptioningDatasetWithKnowledge(dataset_dict, 'test', max_target_length)

# %%
from transformers import Seq2SeqTrainer, Seq2SeqTrainingArguments

training_args = Seq2SeqTrainingArguments(
    predict_with_generate=True,
    evaluation_strategy="epoch",
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    output_dir="./image-captioning-output",
)

from transformers import default_data_collator

# # instantiate trainer
# trainer = Seq2SeqTrainer(
#     model=model,
#     tokenizer=feature_extractor,
#     args=training_args,
#     compute_metrics=compute_metrics,
#     train_dataset=processed_dataset['train'],
#     eval_dataset=processed_dataset['validation'],
#     data_collator=default_data_collator,
# )

# instantiate trainer
trainer = Seq2SeqTrainer(
    model=model,
    tokenizer=feature_extractor,
    args=training_args,
    compute_metrics=compute_metrics,
    train_dataset=train_ds,
    eval_dataset=eval_ds,
    data_collator=default_data_collator,
)

trainer.train()
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# ***** Running training *****
#   Num examples = 353
#   Num Epochs = 3
#   Instantaneous batch size per device = 4
#   Total train batch size (w. parallel, distributed & accumulation) = 4
#   Gradient Accumulation steps = 1
#   Total optimization steps = 267
#   Number of trainable parameters = 239195904
#     <div>
#
#       <progress value='267' max='267' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [267/267 04:03, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.720890</td>
#       <td>30.011900</td>
#       <td>22.690400</td>
#       <td>29.240700</td>
#       <td>29.706600</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.692185</td>
#       <td>30.021400</td>
#       <td>20.959700</td>
#       <td>27.425100</td>
#       <td>29.378500</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.689636</td>
#       <td>29.809800</td>
#       <td>21.080500</td>
#       <td>27.682600</td>
#       <td>29.286300</td>
#       <td>19.000000</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 76
#   Batch size = 4
# ***** Running Evaluation *****
#   Num examples = 76
#   Batch size = 4
# ***** Running Evaluation *****
#   Num examples = 76
#   Batch size = 4
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=267, training_loss=0.8971670200762231, metrics={'train_runtime': 244.401, 'train_samples_per_second': 4.333, 'train_steps_per_second': 1.092, 'total_flos': 1.9111126069621555e+17, 'train_loss': 0.8971670200762231, 'epoch': 3.0})

# %%
trainer.save_model("./new_image-captioning-output-with-llm")
tokenizer.save_pretrained("./new_image-captioning-output-with-llm")
# Out:
# Saving model checkpoint to ./image-captioning-output-with-llm
# Configuration saved in ./image-captioning-output-with-llm\config.json
# Model weights saved in ./image-captioning-output-with-llm\pytorch_model.bin
# Feature extractor saved in ./image-captioning-output-with-llm\preprocessor_config.json
# tokenizer config file saved in ./image-captioning-output-with-llm\tokenizer_config.json
# Special tokens file saved in ./image-captioning-output-with-llm\special_tokens_map.json
# ('./image-captioning-output-with-llm\\tokenizer_config.json',
#  './image-captioning-output-with-llm\\special_tokens_map.json',
#  './image-captioning-output-with-llm\\vocab.json',
#  './image-captioning-output-with-llm\\merges.txt',
#  './image-captioning-output-with-llm\\added_tokens.json',
#  './image-captioning-output-with-llm\\tokenizer.json')

# %%
# Get predictions from the model
predictions = trainer.predict(test_ds)

# Process and evaluate the predictions
preds = predictions.predictions
labels = predictions.label_ids

# Post-process the predictions and labels
decoded_preds = tokenizer.batch_decode(preds, skip_special_tokens=True)
decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

# Calculate evaluation metrics
from nltk.translate.bleu_score import sentence_bleu, corpus_bleu
bleu_scores = []

# Print the actual captions and predicted captions
for actual_caption, predicted_caption in zip(decoded_labels, decoded_preds):
#     actual_caption = actual_caption.split("</s>")[0]
#     predicted_caption = predicted_caption.split("</s>")[0]
    bleu_score = sentence_bleu([actual_caption.split()], predicted_caption.split())
    bleu_scores.append(bleu_score)
    print("Actual Caption:", actual_caption)
    print("Predicted Caption:", predicted_caption)
    print("Blue score: ", bleu_score)
    print("--------------")

average_bleu_score = sum(bleu_scores) / len(bleu_scores)

# Print average BLEU score
print("Average BLEU score:", average_bleu_score)
# Out:
# ***** Running Prediction *****
#   Num examples = 76
#   Batch size = 4
# Actual Caption:  Diffusion-weighted image shows acute infarct in left parieto-occipital area
#  </s> The UMLS semantic types describe the diagnosis for diffusion MRI (Intellectual Product) showing Acute Infarction in left parieto-occipital area.
# Predicted Caption:  The UMLS semantic types describe the diagnosis for MRI procedure (Diagnostic Procedure) using
# Blue score:  0.16825572285877524
# --------------
# Actual Caption:  Transverse view of lung using computed tomography. Leukemic infiltration is seen.
#  </s> Transverse view of lung using computed tomography (Diagnostic Procedure) shows Leukemic infiltration seen (Sign or Symptom). The anatomical location affected by the disease is Lung (Body Part, Organ, or Organ Component).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  1.5618762825312226e-232
# --------------
# Actual Caption:  Facial skull radiograph. Note sclerosis of the orbits and sphenoid bones resulting in “Harlequin mask appearance’’
#  </s> Facial skull radiograph (Diagnostic Procedure) shows Sclerosis of the Orbits and Sphenoid Bones resulting in “Harlequin Mask Appearance” (Sign or Symptom). The affected body parts are Head/Neck (Body Part, Organ, or Organ Component), specifically 2. Eyes, 3. Nose.
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  7.122441669310064e-233
# --------------
# Actual Caption:  MRI showing that the mass was greatly enhanced, with a clear portion in the nearby tissues.MRI showing that the mass was greatly enhanced, with a clear portion in the nearby tissues
#  </s> The UMLS semantic types describe the diagnosis for MRI procedure (Therapeutic Procedure) using Contrast agent (Medical Device). The anatomical location affected by the disease is Breast tissue (Body Part, Organ, or Organ Component), and a mass with clear portion in nearby tissues was observed.
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.008269711168485603
# --------------
# Actual Caption:  Axial fat-suppressed T2-weighted MRI showed subcutaneous oedema and interfascial plane swelling at the right gluteal region, as well as a subcutaneous fibrogranulation tract (arrow) that corresponded to the acupuncture insertion tract.
#  </s> The UMLS semantic types describe the diagnosis for MRI procedure (Diagnostic Procedure) using Indicator, Reagent, or Diagnostic Aid - Contrast Media and Intravenous Solutions (IVD). The anatomical location affected by the disease is the  Gluteal Region, which belongs to Body Part, Organ, or Organ Component.
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.008602841812730752
# --------------
# Actual Caption:  Coronal T1-weighted magnetic resonance imaging showing a tumor with homogenous low-signal intensity and well-defined margins.
#  </s> The UMLS semantic types describe the diagnosis for MRI procedure (Health Care Activity) using Tumor with homogenous low-signal intensity and well defined margins as a finding (Finding).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for MRI procedure (Diagnostic Procedure) using
# Blue score:  0.07500814917097944
# --------------
# Actual Caption:  MRI (cross-sectional view) (arrow) showing T2-weighted hypointense lesion within the pancreatic body
#  </s> The UMLS semantic types describe the diagnosis for MRI procedure (Procedural Diagnosis) using Gadolinium as a Pharmacologic Substance to identify Hypointense lesion within Pancreatic Body (Finding).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.11621672025076547
# --------------
# Actual Caption:  CECT abdomen showing the lesion.
#  </s> The UMLS semantic types describe the diagnosis for catheterization procedure (Therapeutic Procedure) using Cardiopulmonary bypass circuit (Medical Device).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for MRI procedure (Diagnostic Procedure) using
# Blue score:  0.26871487913206205
# --------------
# Actual Caption:  A repeated PET/CT reveals disseminated multiple bony lytic lesions with increased FDG uptake.
#  </s> The diagnosis is Multiple myeloma (Finding) being treated using Bisphosphonate therapy (Pharmacologic substance).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for MRI procedure (Diagnostic Procedure) using
# Blue score:  4.30131302740741e-232
# --------------
# Actual Caption:  CT showing gutta percha point communicating with the periapical area
#  </s> The UMLS semantic types describe the diagnosis for procedure (Therapeutic Procedure) using Gutta percha point (Medical device). The anatomical location affected by the disease is Dental Pulp (Body Part, Organ, or Organ Component), which communicates with Periapical Area (Finding.CT).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.04155624085334673
# --------------
# Actual Caption:  The intraoral radiograph revealed a complete fill of the intrabony defect and a significant improvement in vertical dimension of the resorbed ridge. At 2 years after insertion of the implants, a stable periimplant condition can be observed
#  </s> The UMLS semantic types describe the diagnosis for radiograph procedure (Diagnostic Procedure) using Dental Implant (Medical Device).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.030787699613969533
# --------------
# Actual Caption:  A 30-year-old-woman with genital tuberculosis. Hysterosalpingogram shows a beaded appearance at the right and left fallopian tubes associated with bilateral tubal occlusion (arrows). There is mild irregularity of the uterine cavity outline
#  </s> The UMLS semantic types describe the diagnosis for genital tuberculosis (Pathologic Function) using hysterosalpingogram (Diagnostic Procedure). It shows bilateral tubal occlusion associated with beaded appearance at right and left fallopian tubes on patient 30-years old woman. The anatomical location affected by the disease is Female Reproductive System, Genital Organs (Body Part, Organ, or Organ Component).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for MRI procedure (Diagnostic Procedure) using
# Blue score:  0.001846632245725906
# --------------
# Actual Caption:  Upper gastrointestinal series. Polypous masses in the bulb and the prepyloric part of the stomach
#  </s> The UMLS semantic types describe the gastrointestinal series (Procedure) using Pharmacologic Substance Polypous masses in bulb and prepyloric part of stomach (Anatomic Findings).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.060971254699400484
# --------------
# Actual Caption:  Color Doppler ultrasound image demonstrates multiple tortuous venous structures in the hepatic hilum, keeping with the cavernomatous transformation of the portal vein.
#  </s> The UMLS semantic types describe the diagnosis for ultrasound procedure (Diagnostic Procedure) using Tissue Marker (Indicator, Reagent, or Diagnostic Aid). It is operating on Liver (Body Part, Organ, or Organ Component), specifically its Hilum (Body Location or Region).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.02005631002007356
# --------------
# Actual Caption:  Contrast-enhanced axial CT brainMultiple solid enhancing cortical lesions with dense gyriform calcifications are seen in both cerebral hemispheres. CT- computed tomography
#  </s> The UMLS semantic types describe the diagnosis for CT brain (Diagnostic Procedure) using Contrast agent (Pharmacologic Substance). The anatomical location affected by the disease is Brain (Body Part, Organ, or Organ Component), specifically its cortical regions.
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.02346756229240408
# --------------
# Actual Caption:  Coronal T2-weighted MRI shows a lack of normal signal void of the left internal carotid artery.
#  </s> The UMLS semantic types describe an MRI scan showing a lack of normal signal void (Sign or Symptom) in the left internal carotid artery located inside the Head and Neck Anatomy (Body Part, Organ, or Organ Component).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the procedure (Therapeutic Procedure) using
# Blue score:  0.01342765017304415
# --------------
# Actual Caption:  Castleman disease. Contrast-enhanced chest CT scan shows matted lymphadenopathy (arrows) formed by confluence of inhomogeneously enhancing enlarged lymph nodes confined to anterior mediastinum.
#  </s> The UMLS semantic types describe the diagnosis for CT scan procedure (Diagnostic Procedure) using Contrast agent (Pharmacologic Substance). It is a disease of lymph nodes called Castleman Disease, which mimics lymphoma or sarcoma.
# Predicted Caption:  The UMLS semantic types describe the diagnosis for MRI procedure (Diagnostic Procedure) using
# Blue score:  0.025796246311202333
# --------------
# Actual Caption:  The tibial tubercle–trochlear groove (TT-TG) distance is determined by a line from the most anterior point of the tibial tuberosity to the line running through the trochlear groove (orange). Modified from Cooney et al28 with permission.
#  </s> The UMLS semantic types describe the measurement of distance between tibial tubercle and trochlear groove (Finding).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.022430071106337122
# --------------
# Actual Caption:  Computed tomography (CT) guided needle biopsy of the left upper lobe lesion.
#  </s> The UMLS semantic types describe the biopsy procedure (Diagnostic Procedure) using CT Guided Needle Biopsy (Medical Device). It involves a lesion in the Lung (Body Part, Organ, or Organ Component), which is affected by Health Care Activity.
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.030972423040187772
# --------------
# Actual Caption:  Panoramic radiograph showing extensive radio-opaque lesion with well-defined corticated border.
#  </s> The UMLS semantic types describe the diagnosis for radiograph procedure (Diagnostic Procedure) using Iodine-123 Metaiodobenzylguanidine (Pharmacologic Substance).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.20682212630532915
# --------------
# Actual Caption:  Magnetic resonance angiography image showing almost complete thrombosis of the basilar artery (arrow). This is an extension from the vertebral artery dissection and thrombosis.
#  </s> The UMLS semantic types describe the diagnosis for angiography procedure (Diagnostic Procedure) using Contrast agent (Pharmacologic Substance). It involves an abnormality of Vessel, Artery in this case due to Vertebral artery dissection and thrombosis.
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.023136257165920847
# --------------
# Actual Caption:  Focal steatosis of the liver parenchyma
#  </s> The UMLS semantic types describe a disease (Diseases) of the Liver (Body Part, Organ, or Organ Component).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.14156491952964662
# --------------
# Actual Caption:  Proton-density, fat saturation coronal sequence demonstrating the bony prominence at the femoral head-neck junction (arrow). Also evident is a subtle, adjacent articular cartilage signal irregularity consistent with chondrosis.
#  </s> The UMLS semantic types describe the disease of Chondrosis (Disease or Syndrome) using Sodium chloride (Inorganic Chemical). There is an adjacent Artifact (Artificial Object), Finding (Sign or Symptom) and Lab Test Procedure (Laboratory Procedure). The affected Body Part, Organ, or Organ Component is the Knee Joint.
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the procedure (Therapeutic Procedure) using
# Blue score:  0.003470806342994026
# --------------
# Actual Caption:  Upper contrast study gastric distension with no opacification of the bulb or the duodenum
#  </s> The UMLS semantic types describe the diagnosis for contrast study of gastric distension (Diagnostic Procedure) on an unspecified body part (Body Part, Organ, or Organ Component).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for MRI procedure (Diagnostic Procedure) using
# Blue score:  0.07096104297477725
# --------------
# Actual Caption:  Apical four-chamber view showing large vegetation attached with the tricuspid valve leaflet
#  </s> The UMLS semantic types describe the diagnosis for catheterization procedure (Therapeutic Procedure) using Cardiopulmonary bypass circuit (Medical Device).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.1614492042155934
# --------------
# Actual Caption:  Coupe axiale d’un scanner abdominal passant par le foie après injection du PC
#  </s> The UMLS semantic types describe the diagnosis for Liver (Body Part, Organ, or Organ Component).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.17613695101829202
# --------------
# Actual Caption:  Barium swallow demonstrating the obstructive appearance of the GCT.
#  </s> The UMLS semantic type describes the diagnosis for barium swallow (Procedure).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  2.9643038300269943e-78
# --------------
# Actual Caption:  SANT of the spleen: 99mTc-sulfur colloid scan findings. SPECT CT shows normal tracer activity within the liver and spleen with essentially no activity within the splenic lesion, confirming the absence of reticuloendothelial elements within this abnormality.
#  </s> The UMLS semantic types describe the diagnosis for SPECT CT procedure (Diagnostic Procedure) using Tc-sulfur colloid tracer (Indicator, Reagent, or Diagnostic Aid). It shows normal activity within liver and spleen (Body Part, Organ, or Organ Component), confirming absence of reticuloendothelial elements within the abnormality. The lesion is identified as 7. Neoplastic Process.
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the procedure (Therapeutic Procedure) using
# Blue score:  0.0018504035174568445
# --------------
# Actual Caption:  AP radiograph showing the displaced hip prosthesis into the pelvic cavity.
#  </s> The UMLS semantic types describe the diagnosis for radiograph procedure (Diagnostic Procedure) using Hip Prosthesis (Medical Devices). It is placed in the Pelvic Cavity (Body Part, Organ, or Organ Component).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.07792031294816527
# --------------
# Actual Caption:  Axial T2-weighted image of MRI showing hyperintensity at the center and hypointensity at periphery, suggesting peripheral tumor location with central intratumoral hematoma. MRI = magnetic resonance imaging.
#  </s> The diagnosis is of a peripheral tumor with intratumoral hematoma based on the MRI (Intellectual Product).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  1.6522957397040563e-232
# --------------
# Actual Caption:  X-ray control of calcaneus drilling
#  </s> The UMLS semantic type describes an imaging for the Foot (Body Part, Organ, or Organ Component).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  1.985534733670227e-78
# --------------
# Actual Caption:  Radiographie montrant une ostéolyse des genoux et une périostite chez un 2 mois et 22 jours pris en charge pour syphilis congénitale révélée par une fracture spontanée
#  </s> The UMLS semantic types describe the diagnosis for radiography of congenital syphilis (Diagnositc Procedure) involving injury to Periosteum and Osteolysis at Knee joint (Injury or Poisoning).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.02953415935027726
# --------------
# Actual Caption:  A chest radiograph shows reticulonodular shadowing with bilateral apical lung fibrosis and high density nodules in coal workers pneumoconiosis
#  </s> The UMLS semantic types describe the diagnosis for chest radiograph (Diagnostic Procedure) using Coal Workers' Pneumoconiosis (Intellectual Product). It affects the lungs and causes reticulonodular shadowing with bilateral apical lung fibrosis, leading to high density nodules.
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.02707135837603775
# --------------
# Actual Caption:  CT showing a large multilobulated cystic collection extending to the pelvis.
#  </s> The UMLS semantic types describe the diagnosis for CT procedure (Health Care Activity) using Large Multilobulated Cystic Collection (Medical Device).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the procedure (Therapeutic Procedure) using
# Blue score:  0.14045447642518039
# --------------
# Actual Caption:   Preoperative computed tomography scan: lipid formation without any capsular structure in the perineum.
#  </s> The diagnosis is based on Preoperative computed tomography scan (Diagnostic Procedure) of Lipid formation without any capsular structure in the perineum (Intellectual Product).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  2.72417513153728e-232
# --------------
# Actual Caption:  Postoperative anteroposterior radiograph after bilateral cemented arthroplasty.
#  </s> The diagnosis is related to the Arthrosis (Disease) treated with Surgery, Knee artery ligation (Therapeutic Procedure). No medical devices were used for this procedure and there are no signs or symptoms associated with it.
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  1.906030526536918e-232
# --------------
# Actual Caption:  Radiographs show healing of the fracture at 53 days postoperatively.
#  </s> The diagnosis is that the fracture has healed at day 53 postoperative (Diagnositc Procedure). Pre- and postsurgical radiographs show resolution of displacement, alignment, rotation, angulation; shortening/lengthening are not specified in the UMLS semantic types. The anatomy involved is Bone (Body Part, Organ or Organ Component), specifically 53 days postoperative Humerus fracture with no displacement on AP and lateral radiographs.
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  1.1641642370487481e-156
# --------------
# Actual Caption:  High left parasternal projection. Blue color is used to mark the flow in the descending aorta (AoD), red color to mark the upward movement in the vein located leftward from the aorta which drains into the left venous angle (V). Additional markings: LB – left brachiocephalic vein
#  </s> High left parasternal projection is an indicator used in the diagnosis of organisms function (Mental Process) using blue color to mark flow in descending aorta and red color for vein located leftward from it which drains into left venous angle. The affected body parts are AoD, LB – Left brachiocephalic vein..
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  1.4015511237578824e-157
# --------------
# Actual Caption:  Coronal view of a temporal maximum intensity projection visualizing part of the middle cerebral artery including the M1, M2 and M3 segments. Intensity differences from proximal to distal in a nonaffected vessel can reach up to 450 HU and higher. Vessel occlusions, vessel wall calcifications, collateral flow, clip and stent artifacts have a large influence on the continuity of intensity values along the vessel.
#  </s> The UMLS semantic types describe the diagnosis for catheterization procedure (Therapeutic Procedure) using Cardiopulmonary bypass circuit (Medical Device).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.003934976280101733
# --------------
# Actual Caption:  Chest X-ray, PA, showing the position of the gun nails
#  </s> The UMLS semantic types describe the diagnosis for procedure (Therapeutic Procedure) using Gun Nails (Medical Device). It affects the Lung (Body Part, Organ, or Organ Component), which is located in the Thoracic Cavity (Body Location or Region).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.0479378247678508
# --------------
# Actual Caption:  Concentric reduction of both femoral heads after close reduction.
#  </s> The UMLS semantic types describe the diagnosis for procedure (Therapeutic Procedure) on Knee (Body Part, Organ, or Organ Component).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.18140055226772764
# --------------
# Actual Caption:  CT image showing the hydatic cyst that PAIR was performed.
#  </s> The UMLS semantic types describe a diagnosis of Hydatid Cyst (Disease/Syndrome) using CT image (Intellectual Product).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.11425955890576761
# --------------
# Actual Caption:  Computed tomography revealing right upper-lung pneumonia, the air–fluid level, and septic embolism
#  </s> Computed tomography revealing (Pathology) pneumonia in the right upper lung (Body Part, Organ, or Organ Component). The procedure used is Radiologic Examination, Test, or Result (Diagnostic Procedure), which indicates the presence of air–fluid level and septic embolism (Sign or Symptom).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the procedure (Therapeutic Procedure) using
# Blue score:  6.255280220814505e-233
# --------------
# Actual Caption:  Computed tomography with contrast medium (portal phase). The presence of abscess was suspected at the right lobe of the liver.
#  </s> The UMLS semantic types describe the diagnosis for CT procedure (Diagnostic Procedure) using Contrast Media (Indicator, Reagent, or Diagnostic Aid). It is suspected that there might be an Abscess at the Right Lobe of Liver disease (Disease or Syndrome), which involves Mental Processes. The treatment plans include Needle Aspiration (Therapeutic Procedure) on Body Parts, Organ, and Organ Components such as 7. Heart, Lung, Kidney, Spleen, Colon, Duodenum, Stomach, Abdomen, Pelvis, Right Lower Quadrant of the body. The suspected Abscess
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.0012371737356554604
# --------------
# Actual Caption:  Abdominal CT image showing marked cecal dilatation.
#  </s> The UMLS semantic types describe the dilatation of Cecum (Body Part, Organ, or Organ Component) using CT Image (Intellectual Product).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.12871222963272919
# --------------
# Actual Caption:  Before PDT, fluorescein angiography shows a predominantly classic subfoveal CNV.Abbreviations: CNV, choroidal neovascularization; PDT, photodynamic therapy.
#  </s> The UMLS semantic types describe the diagnosis for photodynamic therapy (Therapeutic Procedure) using Verteporfin (Pharmacologic Substance). The anatomical location affected by the disease is Retina, Optic Disc and Central Part of Choroid (Body Part, Organ, or Organ Component), which shows a subfoveal choroidal neovascularization (Disease or Syndrome) caused by predominantly classic CNV (Pathologic Function).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the procedure (Therapeutic Procedure) using
# Blue score:  0.00790900944967343
# --------------
# Actual Caption:  Abdomen Doppler ultrasound. A well-defined hypoechoic area (~53×39 mm) at the quadrate lobe of the liver, showing that the internal echo of the mass was heterogeneous.
#  </s> Abdomen Doppler ultrasound describes the detection of a liver tumor (Body Part, Organ, or Organ Component). The mass is further characterized as heterogeneous using UMLS semantic types.
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  3.4878314781729285e-156
# --------------
# Actual Caption:  An abdominal X-ray showing a diffuse opaque area in the upper abdomen without a gastrointestinal gas shadow; this finding was accompanied by a downward dislocation of the transverse colon
#  </s> The UMLS semantic types describe the diagnosis for X-ray procedure (Health Care Activity) using Contrast agent (Medical Device). It is a finding of Dense, diffuse opaque area in upper abdomen with downward displacement of transverse colon (Finding), which was accompanied by Gastrointestinal gas shadow absence (Sign or Symptom). The anatomy involved in the diagnosis are Colon (Body Part, Organ, or Organ Component) and Abdominal region (Body Location or Region).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.001328775849088016
# --------------
# Actual Caption:  A sagittal fat-suppressed proton density–weighted image of the left hip (the same patient as Figure 7) depicts the avulsion injury involving both the direct (arrow) and the indirect (arrowhead) heads of the rectus femoris.
#  </s> The UMLS semantic types describe the diagnosis for surgery procedure (Therapeutic Procedure) using Surgical suture material (Pharmacologic Substance). The anatomical location affected by the disease is Hip Dislocation (Body Part, Organ, or Organ Component), and Injury involved Avulsion of Rectus Femoris through direct (arrow) and indirect (arrowhead) heads.
# Predicted Caption:  The UMLS semantic types describe the diagnosis for MRI procedure (Diagnostic Procedure) using
# Blue score:  0.0028725190142910987
# --------------
# Actual Caption:  Micro-CT image of the rat tibias with the titanium implants.
#  </s> The UMLS semantic types describe the diagnosis for Surgical procedure (Therapeutic Procedure) using Implant, Titanium (Medical Device). No other findings were reported in this case.
# Predicted Caption:  The UMLS semantic types describe the diagnosis for MRI procedure (Diagnostic Procedure) using
# Blue score:  0.10675900083673026
# --------------
# Actual Caption:  At the end of treatment. Posttreatment PET-CT scan showing a borderline enlarged left supraclavicular lymph node (white arrow) with moderate to intense FDG activity (SUVmax 8.4). In the absence of any significant adenopathy elsewhere in the body, this was deemed to be of reactive nature.
#  </s> The UMLS semantic types describe the diagnosis for radiation therapy (Therapeutic Procedure) using Paclitaxel (Pharmacologic Substance). There is no disease present in the body as shown by the PET-CT scan (Diagnostic Procedure), which was normal except for a borderline enlarged left supraclavicular lymph node with moderate to intense FDG activity.
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.0015922704765193839
# --------------
# Actual Caption:  Computed tomography cross-section of the pelvis showing right buttock inflammatory changes and a subcutaneous pocket of air lateral to the natal cleft. The pocket of air corresponds to the described abscess.
#  </s> The UMLS semantic types describe the diagnosis for CT procedure (Diagnostic Procedure) using Inflammatory changes in right buttock against a subcutaneous pocket of air lateral to natal cleft as indicators, reagents, or diagnostic aids (Indicator, Reagent, Diagnostic Aid). The anatomical location affected by the disease is the Pelvis region.
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.004806515483508201
# --------------
# Actual Caption:  Orthopantomograph (OPG) showing radiolucency extending from 13 to 17 regions with 16 root resorption and root displacement in 17, 14
#  </s> Orthopantomograph (Diagnostic Procedure) shows the radiolucency extending from tooth regions with root resorption and displacement in. The anatomical location affected by this process is Jaw (Body Part, Organ, or Organ Component).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  8.212158449895727e-233
# --------------
# Actual Caption:  Retrograde urethrogram showing the fistulous tract (arrow) communicating with the ventral part of the anterior urethra.
#  </s> The diagnosis is Fistula (Disease or Syndrome) located at the Ventral part of Anterior Urethra (Body Part, Organ, or Organ Component). It was obtained using Retrograde urethrogram procedure (Diagnostic Procedure).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  6.018635541133755e-156
# --------------
# Actual Caption:  Navigated 3D SPACE image demonstrated discrete proximal aortic arch narrowing in a 6 month old with a history of arch hypoplasia and coarctation of the aorta who previously underwent an arch augmentation.
#  </s> The UMLS semantic types describe the diagnosis for procedure (Therapeutic Procedure) using Circuit Splitter Pulmonary Artery (Medical Device). It is operated on Aorta (Body Part, Organ, or Organ Component), and the image was acquired in a 6-month old patient with history of arch hypoplasia and coarctation of aorta.
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.004539250892467928
# --------------
# Actual Caption:  Computed tomography scan shows no evidence of tumor recurrence in the right parotid region at 18 months after the third operation.
#  </s> The UMLS semantic types describe the diagnosis for CT scan procedure (Diagnostic Procedure) using Indicator, Reagent, or Diagnostic Aid and there is no evidence of Tumor Recurrence in Body Part, Organ, or Organ Component).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.028665281183274938
# --------------
# Actual Caption:  Chest X-ray findings. Chest radiograph revealed an engorged pulmonary trunk with an abrupt cutoff of pulmonary vascularity in the distal portions bilaterally, indicative of the "Westermark sign" (arrows).
#  </s> The UMLS semantic types describe the diagnosis for chest X-ray procedure (Diagnostic Procedure) using Iodinated Contrast Medium (Pharmacologic Substance). It shows a sign of Westermark, which is an engorged pulmonary trunk with an abrupt cutoff of pulmonary vascularity in the distal portions bilaterally. The affected body part or organ component are lungs and heart (Body Part, Organ, or Organ Component).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.002714326397247969
# --------------
# Actual Caption:  Panoramic view showing multiple impacted permanent and supernumerary teeth, hypoplastic maxillary sinus and slender coronoid process.
#  </s> The UMLS semantic types describe the diagnosis for Panoramic view (Procedure) of multiple Impacted teeth (Dental Device), Hypoplastic maxillary sinus and slender coronoid process (Anatomical Structure).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.06479716311025098
# --------------
# Actual Caption:   Computed tomography axial section after injection of contrast medium in parenchymal time showing a large thrombus in the left renal vein extending from the segmental renal veins to the inferior vena cava, complicated by cortical infarction.
#  </s> The UMLS semantic types describe the diagnosis for CT procedure (Diagnostic Procedure) using Contrast Medium (Indicator, Reagent, or Diagnostic Aid). It is a complication of Renal Infarct (Pathologic Function), which affected the left kidney and resulted in large thrombus in the left renal vein extending from segmental to inferior vena cava.
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.0029152990071312163
# --------------
# Actual Caption:  Radiographic observations at the time of the initial consultation showing an osteolytic lesion with an osteosclerotic change to the femoral neck (arrows).
#  </s> The UMLS semantic types describe the diagnosis for X-ray procedure (Diagnostic Procedure) using Bisphosphonates (Pharmacologic Substance). The anatomical location affected by the disease is Hip Bone (Body Part, Organ, or Organ Component), which shows Osteolytic Lesion.
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.023136257165920847
# --------------
# Actual Caption:  Simple abdominal X-ray presents multiple dilated small bowel loops.
#  </s> The UMLS semantic types describe the diagnosis for X-ray (Finding) of Gastrointestinal Tract disorder (Pathological Process).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.21822956027395587
# --------------
# Actual Caption:  Soft tissue Bankart lesion with a tear of the anterior inferior labrum and an adjacent, small, full-thickness mild (<25%) chondral defect over the anterior inferior glenoid (arrow) on an axial proton density sequence.
#  </s> The UMLS semantic types describe the diagnosis for MRI scan (Procedure) of a soft tissue Bankart lesion with tear of anterior inferior labrum and chondral defect over glenoid (Injury).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.018466849205407948
# --------------
# Actual Caption:  Magnetic resonance of abdomen showing two lesions within the right lobe of the liver along the peripheral surface (black arrows).
#  </s> The UMLS semantic types describe the diagnosis for MRI procedure (Intellectual Product) of two lesions within right lobe liver along peripheral surface (black arrows).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.07570811070950897
# --------------
# Actual Caption:  Image of the TMJ shows the morphology of the TMJ in an asymptomatic volunteer.
#  </s> The UMLS semantic type describes a finding, Asymptomatic Condition.
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  1.5552943887175572e-78
# --------------
# Actual Caption:  Motility Assay.Figure shows motility of the E. coli K12 MG1655 wild type (wt) and strains harboring integrations in the target loci of the flagellar region 1 (flgA (flgAi), flgF (flgFi), flgG (flgGi), flgI (flgIi), and flgJ (flgJi)). 2 μl of the overnight E. coli cultures (OD600 of 1.0) were inoculated in the middle of the motility plates and incubated for 4–6 hours at 37°C.
#  </s> The UMLS semantic types describe the motility assay for E Coli (Organism Function) using Tryptophan (Amino Acid, Peptide, or Protein).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.0024290903362075692
# --------------
# Actual Caption:  Lateral-view radiograph of a wrist that underwent arthrodesis with minimal fixation. Note the dorsal bone plate and the free carpometacarpal joints. The Kirschner wires that had been holding the bone plate and radiocarpal joint have been removed.
#  </s> The UMLS semantic types describe the diagnosis for procedure (Therapeutic Procedure) using Bone Plate (Medical Device). It involves the use of anesthesia (Mental Process), stainless steel plate and screws as medical devices (Intellectual Product, Medical Devices), local anesthetic agent (Pharmacologic Substance), wrist region (Body Part or Organ) for surgery.
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.0030283505948206476
# --------------
# Actual Caption:  Intraoral periapical radiograph taken to check position of the mini-implant.
#  </s> Based on the given diagnosis, it can be inferred that a periapical radiograph was taken to check if an implant is properly placed (Therapeutic Procedure). To do this procedure an X-ray machine and film are used (Diagnostic Device). The image shows only one tooth which suggests the mini-implant has been positioned correctly in that particular location.
# Predicted Caption:  The UMLS semantic types describe the diagnosis for MRI procedure (Diagnostic Procedure) using
# Blue score:  2.1308114411958613e-233
# --------------
# Actual Caption:  Right-sided metatarsal in dorsoplantar projection.Cow. Age group IV—cattle 4–8 years. (a) Narrow symphysis that is (b) indistinct from the bone surface.
#  </s> The UMLS semantic types describe the diagnosis for metatarsal procedure (Therapeutic Procedure) on a cow aged between four to eight years with narrow symphysis indistinct from bone surface..
# Predicted Caption:  The UMLS semantic types describe the diagnosis for MRI procedure (Diagnostic Procedure) using
# Blue score:  0.03434445212708561
# --------------
# Actual Caption:  Postoperative panoramic radiograph after surgery. The costochondral graft was adjusted to the left condyle area and secured on the left mandibular ramus by five bicortical screws for rigid internal fixation
#  </s> The UMLS semantic types describe the radiograph of a surgical procedure (Therapeutic Procedure) using Screw (Medical Device). It was performed on the location Heart Lobe (Body Part, Organ, or Organ Component), which is anatomically related to Tendon Injury.
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.007616934429290854
# --------------
# Actual Caption:  AbdominoPelvic MRI showing a large mass containing fetus in right adnexa in close contact with uterus.
#  </s> The UMLS semantic types describe the diagnosis for MRI procedure (Therapeutic Procedure) using Contrast Media (Indicator, Reagent, or Diagnostic Aid). The anatomical location affected by the disease is AbdominoPelvic region (Body Part, Organ, or Organ Component).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.04275374210062944
# --------------
# Actual Caption:  An angiographic view of a patient whose coarctation was removed surgically by the procedure of subclavian flap angioplasty
#  </s> The UMLS semantic types describe the diagnosis for surgery procedure (Therapeutic Procedure) using Angiographic Equipment (Medical Device).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for MRI procedure (Diagnostic Procedure) using
# Blue score:  0.10675900083673026
# --------------
# Actual Caption:  Hypotonic duodenography showing a contrast media-positive elevated lesion in the center of the duodenal bulb.
#  </s> The UMLS semantic types describe the diagnosis for procedure (Diagnostic Procedure) using Contrast Media (Indicator, Reagent, or Diagnostic Aid). It is operating on Lesion (Finding), which has an elevated center in Duodenal bulb (Body Part, Organ, or Organ Component). The Pharmacologic Substance is 2-aminoisobutyric acid (Dipeptide) and the Pathologic Function describes a tumor.
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.011326161728941337
# --------------
# Actual Caption:  Intraoral periapical radiograph of the patient depicting unusual morphology of mandibular left second premolar
#  </s> The diagnosis is Intraoral periapical radiograph (Diagnostic Procedure) of the patient depicting unusual morphology of mandibular left second premolar (Finding).
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  3.142513071705181e-232
# --------------
# Actual Caption:  MRI revealed a huge mass adjacent to the first and second lumbar vertebrae with extension into the spinal canal.
#  </s> The UMLS semantic types describe the diagnosis for spinal canal (Clinical Attributes) using Imaging Device (Medical Devices). It is a mass of unknown substance surrounding lumbar vertebrae in MRI image (Pharmacologic Substances and Image or Vision Component), potentially affecting mental health.
# Predicted Caption:  The UMLS semantic types describe the diagnosis for MRI procedure (Diagnostic Procedure) using
# Blue score:  0.014735899350942157
# --------------
# Actual Caption:  The vertical distance from the alveolar ridge to the most inferior sinus floor at the projected implant placement site was 7.45 mm in this specific panoramic radiograph before the implant surgery (black line).
#  </s> The UMLS semantic types describe the diagnosis for Dental Implant Surgery (Therapeutic Procedure) using Guide Tool For Drilling And Tapping Holes In Bone (Medical Device). No disease is associated in this case.
# Predicted Caption:  The UMLS semantic types describe the diagnosis for the diagnosis for MRI procedure (Diagnostic
# Blue score:  0.012908040855231447
# --------------
# Actual Caption:  CT head with IV contrast with an arrow that indicates cerebral venous sinus thrombosis.
#  </s> The UMLS semantic types describe the diagnosis for MRI procedure (Diagnostic Procedure) using Contrast agent (Pharmacologic Substance). The anatomical location affected by the disease is Brain (Body Part, Organ, or Organ Component), specifically Cerebral Venous Sinus.
# Predicted Caption:  The UMLS semantic types describe the diagnosis for MRI procedure (Diagnostic Procedure) using
# Blue score:  0.05376799253902107
# --------------
# Average BLEU score: 0.043530846085037773

# %% [markdown]
# # Computing BLEU and ROUGE score

# %%
# import evaluate


# bleu = evaluate.load("bleu")
# rouge = evaluate.load("rouge")


# def calculate_bleu_and_rouge(reference: str, hypothesis: str):
#     """
#     Inputs: Reference -> Target caption, Hypothesis -> Generated caption
#     Outputs: Dictionary of bleu score and rouge score
#     Description: This function computes the bleu score as well as rouge1, rouge2, rougeL, and rougeLsum
#     """
    
#     bleu_score = bleu.compute(predictions=[hypothesis], references=[reference])
#     rouge_score = rouge.compute(
#         predictions=[hypothesis], references=[reference]
#     )

#     return {"bleu_score": bleu_score, "rouge_score": rouge_score}

# %% [raw]
# # Use the below code for reference
#
# for _, row in test_input.iterrows():
#     input_id = row["id"]
#     input_text = row["semtypes"]
#
#     # Tokenize the input text
#     input_ids = tokenizer.encode(input_text, return_tensors="pt")
#     input_ids = input_ids.to(device)
#
#     # Generate captions using the model
#     outputs = model.generate(input_ids)
#
#     # Decode the generated captions
#     generated_captions = tokenizer.decode(outputs[0], skip_special_tokens=True)
#
#     target_caption = test_target[test_target["id"] == input_id]["caption"].values[0]
#
#     # Calculating BLEU score and ROGUE score between the captions
#
#     score = calculate_bleu_and_rouge(target_caption, generated_captions)
#     bleu_score, rouge_score = score["bleu_score"], score["rouge_score"]
#
#     temp = {
#         "id": input_id,
#         "input_text": input_text,
#         "generated_caption": generated_captions,
#         "target_caption": target_caption,
#         "bleu_score": bleu_score,
#         "rouge_score": rouge_score,
#     }
#
#     res.append(temp)
